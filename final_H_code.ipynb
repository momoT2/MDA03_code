# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import numpy as np
import matplotlib
# %matplotlib inline
import seaborn as sns
import missingno as msno
import shap
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %% [markdown]
# ## 탐색적 데이터 분석(EDA)

# %% [markdown]
# ### 결측치 점검

# %%
df_raw = pd.read_csv('C:\\Users\\user\\Downloads\\0827_H2_data.csv')

df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14956 entries, 0 to 14955
# Columns: 257 entries, id to hazard_psy3
# dtypes: float64(178), int64(77), object(2)
# memory usage: 29.3+ MB

# %%
# # 클래스 분포 확인
# print(df_raw['burnout60'].value_counts())
# print("번아웃클래스 이진으로 분류한다면: ", df_raw['burnout60'].value_counts().iloc[1:].sum(), "명")

# %%
# 결측치 개수가 높은 순위 중 타겟과 관련없는 변수 삭제

df = df_raw.drop(['emp_keep_a', 'hazard_phy_d','hazard_phy_a','hazard_phy_c','hazard_phy_e','hazard_phy_f','hazard_phy_g','hazard_phy_h', 'hazard_phy_i', 'ch_downsizing', 'job_c1_r', 'job_c1', 'emp_pay_type', 'skillmat', 'emp_comp_com_a','emp_comp_com_b','emp_comp_com_c','ch_ic','ch_restruct','wplace_sl','emp_noncon', 'wcomback'], axis = 1)

# %%
# 널값 개수와 비율 계산
null_summary = (
    df.isnull().sum()
      .to_frame("널값 개수")
      .assign(널값비율 = lambda x: (x["널값 개수"] / len(df_raw) * 100).round(2))
      .reset_index()
      .rename(columns={'index': '컬럼명'})
)

# 널값 있는 열만 필터링 & 비율 기준 내림차순 정렬
null_summary = (
    null_summary[null_summary["널값 개수"] > 0]
    .sort_values(by="널값비율", ascending=False)
    .reset_index(drop=True)
)

print(null_summary)
# Out:
#                   컬럼명  널값 개수  널값비율
# 0         comp_size_b    870  5.82
# 1        wtime_ftwork    584  3.90
# 2            emp_keep    581  3.88
# 3          emo_manual    307  2.05
# 4    wtime_resilience    279  1.87
# ..                ...    ...   ...
# 150       wsituation7      2  0.01
# 151      wsituation13      1  0.01
# 152            wstat1      1  0.01
# 153         winten2_a      2  0.01
# 154     wtime_length3      2  0.01
#
# [155 rows x 3 columns]

# %%
# start 파일
# df.to_csv("2PD_v1_0822.csv", encoding="CP949")

# %% [markdown]
# ### 중복 피쳐 삭제/8,9->결측치 수정

# %%
# 불필요한 피쳐 삭제하기 (14개)
df = df.drop(columns=["ptime_r", "stratification", "district", "household", "target", "mode", "hh_num", "eli_num", "hm_01_gender", "hm_01_year", "hm_01_estat", "hm_01_rel_t","wtime_week", "earning1_r"])

print(df)
# Out:
#               id burnout60  area  gender  age  wduration_y  earning1  \
# 0      1000042_1       lv1     1       1   49           10       500
# 1      1000051_1       lv2     1       1   31            2       300
# 2      1000056_1       lv1     1       1   32            2       300
# 3      1000069_1       lv1     1       1   38            2       390
# 4      1000069_2       lv1     1       2   37            5       330
# ...          ...       ...   ...     ...  ...          ...       ...
# 14951  2010124_1       lv1     7       1   37            6       450
# 14952  2010133_1       lv2     7       2   46            3       230
# 14953  2010134_2       lv1     7       2   34            5       320
# 14954  2010137_1       lv1     7       1   57            5       450
# 14955  2010137_2       lv1     7       2   29            3       350
#
#        earning2_r  wtime_r  woutside4_a  ...  panel_survey  ind  ind2  occ  \
# 0               6     40.0            1  ...             2    7    46    3
# 1               4     48.0            1  ...             2    7    47    3
# 2               4     50.0            1  ...             2    9    56    4
# 3               4     40.0            1  ...             2    6    42    3
# 4               4     40.0            1  ...             2   13    71    2
# ...           ...      ...          ...  ...           ...  ...   ...  ...
# 14951           5     40.0            1  ...             2   16    85    2
# 14952           3     40.0            1  ...             2    8    52    3
# 14953           4     40.0            1  ...             2   11    64    3
# 14954           5     40.0            1  ...             2    7    46    5
# 14955           4     40.0            1  ...             2   10    61    7
#
#        occ2  comp_sizea_r  comp_sizeb_r  hazard_psy1  hazard_psy2  hazard_psy3
# 0       313           4.0             4            5            4            5
# 1       312          11.0            11            4            4            4
# 2       441           2.0             2            2            2            2
# 3       312          10.0            10            7            7            7
# 4       273           7.0             7            7            7            7
# ...     ...           ...           ...          ...          ...          ...
# 14951   252           6.0             6            6            6            5
# 14952   313           4.0             4            4            5            4
# 14953   320           4.0             4            4            5            5
# 14954   510           4.0             4            3            5            3
# 14955   772           4.0             4            7            6            5
#
# [14956 rows x 221 columns]

# %%
# 전처리: 8, 9 NULL (5개)
cols = ["hazard_erg_a", "hazard_erg_b", "hazard_erg_c", "hazard_erg_d", "hazard_erg_e"]

df[cols] = df[cols].replace([8, 9], pd.NA)

print(df['hazard_erg_a'].unique())
print(df['hazard_erg_b'].unique())
print(df['hazard_erg_c'].unique())
print(df['hazard_erg_d'].unique())
print(df['hazard_erg_e'].unique())
# Out:
# [6 2 1 7 5 4 3 <NA>]
# [1 5 6 3 4 7 2 <NA>]
# [ 7.  6.  2.  5.  4.  3.  1. nan]
# [ 7.  2.  5.  4.  6.  3. nan  1.]
# [ 7.  3.  5.  6.  4.  2.  1. nan]

# %%
# 잘못 변경된 변수명 복원
df.rename(columns={
    "wsituation": "wsituation8",
    "wsituation.1": "wsituation9",
    "disc": "disc9",
    "disc.1": "disc8"
}, inplace=True)

# %% [markdown]
# ### 설문 문항 중 긍부정 변경

# %%
# 원래 이름 확인 필요
df['emp_tra_b'].value_counts()
# Out:
# emp_tra_b
# 2.0    9890
# 1.0    5053
# Name: count, dtype: int64

# %%
df['heal_wsick1'].unique()
df['heal_wsick1'].value_counts()
# Out:
# heal_wsick1
# 2.0    11610
# 7.0     2630
# 1.0      675
# Name: count, dtype: int64

# %%
cols = ["heal_wsick1"]

df[cols] = df[cols].replace(7,2)

print(df['heal_wsick1'].unique())
print(df['heal_wsick1'].value_counts())
# Out:
# [ 2.  1. nan]
# heal_wsick1
# 2.0    14240
# 1.0      675
# Name: count, dtype: int64

# %%
cols = [
   "heal_wsick1"
]

# 변환 딕셔너리 
reverse_map = {1: 2, 2: 1}

# 여러 열에 적용
for col in cols:
    df[col] = df[col].map(reverse_map).fillna(df[col])


print(df['heal_wsick1'].unique())
print(df['heal_wsick1'].value_counts())
# Out:
# [ 1.  2. nan]
# heal_wsick1
# 1.0    14240
# 2.0      675
# Name: count, dtype: int64

# %%
# 2점 척도 변환
cols = [
   "ch_me", 'heal_prob2', 'heal_prob3', 'heal_prob4'
]

# 변환 딕셔너리 
reverse_map = {1: 2, 2: 1}

# 여러 열에 적용
for col in cols:
    df[col] = df[col].map(reverse_map).fillna(df[col])


print(df['ch_me'].unique())
print(df['ch_me'].value_counts())
# Out:
# [ 1.  2. nan]
# ch_me
# 1.0    12538
# 2.0     2273
# Name: count, dtype: int64

# %%
df["wstat4"].head(10)
# Out:
# 0    2
# 1    2
# 2    2
# 3    3
# 4    5
# 5    5
# 6    5
# 7    5
# 8    5
# 9    5
# Name: wstat4, dtype: int64

# %%
# 긍/부정 변경
# 5점 척도

cols = [
    "wstat4", "wstat6",
    "wwa1", "wwa2", "wwa3", "wwa4", "wwa5",
    "sleep1", "sleep2", "sleep3",
    "wsituation12", "wsituation14"
]

# 변환 딕셔너리 (5점 척도 역코딩)
reverse_map = {1: 5, 2: 4, 3: 3, 4: 2, 5: 1}

# 여러 열에 적용
for col in cols:
    df[col] = df[col].map(reverse_map).fillna(df[col])

df["wstat4"].head(10)
# Out:
# 0    4
# 1    4
# 2    4
# 3    3
# 4    1
# 5    1
# 6    1
# 7    1
# 8    1
# 9    1
# Name: wstat4, dtype: int64

# %%
# 3점 척도 
cols_2 = [
   "heal_lim1"
]

# 변환 딕셔너리 (3점 척도 역코딩)
reverse_map = {1: 3, 2: 2, 3: 1}

# 여러 열에 적용
for col in cols_2:
    df[col] = df[col].map(reverse_map).fillna(df[col])


#%%
print(df.columns.tolist())
#%%
print(df[cols_2].head())
#%%
df["heal_lim1"].head(10) 
#%%
# Out:
# ['id', 'burnout60', 'area', 'gender', 'age', 'wduration_y', 'earning1', 'earning2_r', 'wtime_r', 'woutside4_a', 'wtime_length5', 'age_group', 'emp_period_group', 'wtime_group', 'compsize_group', 'woutside_group', 'compsize_group_a', 'wday_week_group_a', 'woutside4_group_a', 'occ_t2_group_a', 'earning2_group_b', 'occ_group_a', 'emp_stat', 'emp_con_term', 'emp_keep', 'emp_own_mgmt', 'emp_fptime', 'emp_wage', 'emp_stat_sp', 'income_pos_a', 'income_pos_b', 'income_pos_c', 'income_pos_d', 'income_pos_e', 'income_pos_f', 'income_pos_g', 'income_pos_h', 'income_pos_i', 'income_pos_j', 'emp_place', 'emp_suggest_a', 'emp_suggest_b', 'emp_boss_gender', 'emp_manaqual_a', 'emp_manaqual_b', 'emp_manaqual_c', 'emp_manaqual_d', 'emp_manaqual_e', 'emp_comp_ass_a', 'emp_comp_ass_b', 'emp_comp_ass_c', 'emp_comp_ass_d', 'emp_comp_ass_e', 'emp_comp_ass_f', 'emp_rep', 'emp_winflu_a', 'emp_winflu_b', 'emp_winflu_c', 'emp_tra_b', 'emp_tra_c', 'emp_tra_d', 'wsector', 'comp_size_a', 'comp_size_b', 'comp_female', 'comp_sjob', 'ch_tech', 'ch_me', 'ch_ps', 'imte1', 'imte2', 'imte3', 'imte4', 'imte5', 'safeinform', 'wsituation1', 'wsituation2', 'wsituation3', 'wsituation4', 'wsituation5', 'wsituation11', 'wsituation6', 'wsituation7', 'wsituation8', 'wsituation9', 'wsituation10', 'wsituation12', 'wsituation13', 'wsituation14', 'wstat1', 'wstat2', 'wstat3', 'wstat4', 'wstat5', 'wstat6', 'wstat7', 'emo_manual', 'asb5', 'asb6', 'asb7', 'disc1', 'disc5', 'disc9', 'disc10', 'disc11', 'disc6', 'disc7', 'disc8', 'disc2', 'disc3', 'disc4', 'wtime_con1', 'wday', 'wday_week', 'ctime', 'wtime_night_a', 'wtime_sun_a', 'wtime_sat_a', 'wtime_long_a', 'wtime_night2', 'wtime_night3', 'wtime_resilience', 'wtime_arr_a', 'wtime_ftwork', 'wtime_ftcomtool', 'wtime_private', 'hazard_phy_b', 'hazard_erg_a', 'hazard_erg_b', 'hazard_erg_c', 'hazard_erg_d', 'hazard_erg_e', 'winten2_a', 'winten2_b', 'winten1_a', 'winten1_b', 'decla_a', 'decla_b', 'decla_c', 'winten3_a', 'winten3_b', 'winten3_c', 'winten3_d', 'winten3_e', 'winterrupt1', 'weng1', 'weng2', 'weng3', 'weng4', 'weng5', 'condim1', 'condim2', 'condim3', 'condim4', 'condim5', 'condim6', 'ass_cust1', 'alter_task1', 'wteam1', 'satisfaction', 'wplace4', 'wplace3', 'wplace2', 'wplace1', 'wpalce_ch', 'wtime_length1', 'wtime_length2', 'wtime_length3', 'wtime_length4', 'job1', 'wtime', 'wbalance', 'wwa1', 'wwa2', 'wwa3', 'wwa4', 'wwa5', 'heal_risk', 'heal_abs1', 'heal_wsick1', 'asb1', 'asb2', 'asb3', 'asb4', 'heal_aff', 'heal_cond', 'heal_illhe', 'heal_lim1', 'heal_prob1', 'heal_prob2', 'heal_prob3', 'heal_prob4', 'heal_prob5', 'heal_prob6', 'heal_prob8', 'sleep1', 'sleep2', 'sleep3', 'who1', 'who2', 'who3', 'who4', 'who5', 'woutside3', 'woutside4', 'woutside5', 'income_con', 'income_bal', 'edu', 'marital', 'children', 'panel_survey', 'ind', 'ind2', 'occ', 'occ2', 'comp_sizea_r', 'comp_sizeb_r', 'hazard_psy1', 'hazard_psy2', 'hazard_psy3']
#    heal_lim1
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# 5    1.0
# 6    1.0
# 7    1.0
# 8    1.0
# 9    1.0
# Name: heal_lim1, dtype: float64

# %%
# 4점 척도
cols_1 = [
    "imte1", "imte2", "imte3", "imte4", "imte5",
]

# 변환 딕셔너리 (4점 척도 역코딩)
reverse_map = {1: 4, 2: 3, 3: 2, 4: 1}

# 여러 열에 적용
for col in cols_1:
    df[col] = df[col].map(reverse_map).fillna(df[col])


#%%
print(df.columns.tolist())
#%%
print(df[cols_1].head())
#%%
df["imte1"].head(10) 
#%%
# Out:
# ['id', 'burnout60', 'area', 'gender', 'age', 'wduration_y', 'earning1', 'earning2_r', 'wtime_r', 'woutside4_a', 'wtime_length5', 'age_group', 'emp_period_group', 'wtime_group', 'compsize_group', 'woutside_group', 'compsize_group_a', 'wday_week_group_a', 'woutside4_group_a', 'occ_t2_group_a', 'earning2_group_b', 'occ_group_a', 'emp_stat', 'emp_con_term', 'emp_keep', 'emp_own_mgmt', 'emp_fptime', 'emp_wage', 'emp_stat_sp', 'income_pos_a', 'income_pos_b', 'income_pos_c', 'income_pos_d', 'income_pos_e', 'income_pos_f', 'income_pos_g', 'income_pos_h', 'income_pos_i', 'income_pos_j', 'emp_place', 'emp_suggest_a', 'emp_suggest_b', 'emp_boss_gender', 'emp_manaqual_a', 'emp_manaqual_b', 'emp_manaqual_c', 'emp_manaqual_d', 'emp_manaqual_e', 'emp_comp_ass_a', 'emp_comp_ass_b', 'emp_comp_ass_c', 'emp_comp_ass_d', 'emp_comp_ass_e', 'emp_comp_ass_f', 'emp_rep', 'emp_winflu_a', 'emp_winflu_b', 'emp_winflu_c', 'emp_tra_b', 'emp_tra_c', 'emp_tra_d', 'wsector', 'comp_size_a', 'comp_size_b', 'comp_female', 'comp_sjob', 'ch_tech', 'ch_me', 'ch_ps', 'imte1', 'imte2', 'imte3', 'imte4', 'imte5', 'safeinform', 'wsituation1', 'wsituation2', 'wsituation3', 'wsituation4', 'wsituation5', 'wsituation11', 'wsituation6', 'wsituation7', 'wsituation8', 'wsituation9', 'wsituation10', 'wsituation12', 'wsituation13', 'wsituation14', 'wstat1', 'wstat2', 'wstat3', 'wstat4', 'wstat5', 'wstat6', 'wstat7', 'emo_manual', 'asb5', 'asb6', 'asb7', 'disc1', 'disc5', 'disc9', 'disc10', 'disc11', 'disc6', 'disc7', 'disc8', 'disc2', 'disc3', 'disc4', 'wtime_con1', 'wday', 'wday_week', 'ctime', 'wtime_night_a', 'wtime_sun_a', 'wtime_sat_a', 'wtime_long_a', 'wtime_night2', 'wtime_night3', 'wtime_resilience', 'wtime_arr_a', 'wtime_ftwork', 'wtime_ftcomtool', 'wtime_private', 'hazard_phy_b', 'hazard_erg_a', 'hazard_erg_b', 'hazard_erg_c', 'hazard_erg_d', 'hazard_erg_e', 'winten2_a', 'winten2_b', 'winten1_a', 'winten1_b', 'decla_a', 'decla_b', 'decla_c', 'winten3_a', 'winten3_b', 'winten3_c', 'winten3_d', 'winten3_e', 'winterrupt1', 'weng1', 'weng2', 'weng3', 'weng4', 'weng5', 'condim1', 'condim2', 'condim3', 'condim4', 'condim5', 'condim6', 'ass_cust1', 'alter_task1', 'wteam1', 'satisfaction', 'wplace4', 'wplace3', 'wplace2', 'wplace1', 'wpalce_ch', 'wtime_length1', 'wtime_length2', 'wtime_length3', 'wtime_length4', 'job1', 'wtime', 'wbalance', 'wwa1', 'wwa2', 'wwa3', 'wwa4', 'wwa5', 'heal_risk', 'heal_abs1', 'heal_wsick1', 'asb1', 'asb2', 'asb3', 'asb4', 'heal_aff', 'heal_cond', 'heal_illhe', 'heal_lim1', 'heal_prob1', 'heal_prob2', 'heal_prob3', 'heal_prob4', 'heal_prob5', 'heal_prob6', 'heal_prob8', 'sleep1', 'sleep2', 'sleep3', 'who1', 'who2', 'who3', 'who4', 'who5', 'woutside3', 'woutside4', 'woutside5', 'income_con', 'income_bal', 'edu', 'marital', 'children', 'panel_survey', 'ind', 'ind2', 'occ', 'occ2', 'comp_sizea_r', 'comp_sizeb_r', 'hazard_psy1', 'hazard_psy2', 'hazard_psy3']
#    imte1  imte2  imte3  imte4  imte5
# 0    3.0    3.0    3.0    4.0    4.0
# 1    3.0    3.0    4.0    4.0    3.0
# 2    3.0    3.0    2.0    2.0    3.0
# 3    1.0    1.0    1.0    2.0    1.0
# 4    2.0    2.0    3.0    1.0    2.0
# 0    3.0
# 1    3.0
# 2    3.0
# 3    1.0
# 4    2.0
# 5    2.0
# 6    2.0
# 7    3.0
# 8    2.0
# 9    2.0
# Name: imte1, dtype: float64

# %%
# 7점 척도
cols_1 = [
    "hazard_erg_a", "hazard_erg_b", "hazard_erg_c", "hazard_erg_d", "hazard_erg_e", 'hazard_psy1', 'hazard_psy2', 'hazard_psy3'
]

# 변환 딕셔너리 (7점 척도 역코딩)
reverse_map = {1: 7, 2: 6, 3: 5, 5: 3, 6: 2, 7: 1}

# 여러 열에 적용
for col in cols_1:
    df[col] = df[col].map(reverse_map).fillna(df[col])


#%%
print(df.columns.tolist())
#%%
print(df[cols_1].head())
#%%
df["hazard_erg_a"].head(10) 
#%%
# Out:
# ['id', 'burnout60', 'area', 'gender', 'age', 'wduration_y', 'earning1', 'earning2_r', 'wtime_r', 'woutside4_a', 'wtime_length5', 'age_group', 'emp_period_group', 'wtime_group', 'compsize_group', 'woutside_group', 'compsize_group_a', 'wday_week_group_a', 'woutside4_group_a', 'occ_t2_group_a', 'earning2_group_b', 'occ_group_a', 'emp_stat', 'emp_con_term', 'emp_keep', 'emp_own_mgmt', 'emp_fptime', 'emp_wage', 'emp_stat_sp', 'income_pos_a', 'income_pos_b', 'income_pos_c', 'income_pos_d', 'income_pos_e', 'income_pos_f', 'income_pos_g', 'income_pos_h', 'income_pos_i', 'income_pos_j', 'emp_place', 'emp_suggest_a', 'emp_suggest_b', 'emp_boss_gender', 'emp_manaqual_a', 'emp_manaqual_b', 'emp_manaqual_c', 'emp_manaqual_d', 'emp_manaqual_e', 'emp_comp_ass_a', 'emp_comp_ass_b', 'emp_comp_ass_c', 'emp_comp_ass_d', 'emp_comp_ass_e', 'emp_comp_ass_f', 'emp_rep', 'emp_winflu_a', 'emp_winflu_b', 'emp_winflu_c', 'emp_tra_b', 'emp_tra_c', 'emp_tra_d', 'wsector', 'comp_size_a', 'comp_size_b', 'comp_female', 'comp_sjob', 'ch_tech', 'ch_me', 'ch_ps', 'imte1', 'imte2', 'imte3', 'imte4', 'imte5', 'safeinform', 'wsituation1', 'wsituation2', 'wsituation3', 'wsituation4', 'wsituation5', 'wsituation11', 'wsituation6', 'wsituation7', 'wsituation8', 'wsituation9', 'wsituation10', 'wsituation12', 'wsituation13', 'wsituation14', 'wstat1', 'wstat2', 'wstat3', 'wstat4', 'wstat5', 'wstat6', 'wstat7', 'emo_manual', 'asb5', 'asb6', 'asb7', 'disc1', 'disc5', 'disc9', 'disc10', 'disc11', 'disc6', 'disc7', 'disc8', 'disc2', 'disc3', 'disc4', 'wtime_con1', 'wday', 'wday_week', 'ctime', 'wtime_night_a', 'wtime_sun_a', 'wtime_sat_a', 'wtime_long_a', 'wtime_night2', 'wtime_night3', 'wtime_resilience', 'wtime_arr_a', 'wtime_ftwork', 'wtime_ftcomtool', 'wtime_private', 'hazard_phy_b', 'hazard_erg_a', 'hazard_erg_b', 'hazard_erg_c', 'hazard_erg_d', 'hazard_erg_e', 'winten2_a', 'winten2_b', 'winten1_a', 'winten1_b', 'decla_a', 'decla_b', 'decla_c', 'winten3_a', 'winten3_b', 'winten3_c', 'winten3_d', 'winten3_e', 'winterrupt1', 'weng1', 'weng2', 'weng3', 'weng4', 'weng5', 'condim1', 'condim2', 'condim3', 'condim4', 'condim5', 'condim6', 'ass_cust1', 'alter_task1', 'wteam1', 'satisfaction', 'wplace4', 'wplace3', 'wplace2', 'wplace1', 'wpalce_ch', 'wtime_length1', 'wtime_length2', 'wtime_length3', 'wtime_length4', 'job1', 'wtime', 'wbalance', 'wwa1', 'wwa2', 'wwa3', 'wwa4', 'wwa5', 'heal_risk', 'heal_abs1', 'heal_wsick1', 'asb1', 'asb2', 'asb3', 'asb4', 'heal_aff', 'heal_cond', 'heal_illhe', 'heal_lim1', 'heal_prob1', 'heal_prob2', 'heal_prob3', 'heal_prob4', 'heal_prob5', 'heal_prob6', 'heal_prob8', 'sleep1', 'sleep2', 'sleep3', 'who1', 'who2', 'who3', 'who4', 'who5', 'woutside3', 'woutside4', 'woutside5', 'income_con', 'income_bal', 'edu', 'marital', 'children', 'panel_survey', 'ind', 'ind2', 'occ', 'occ2', 'comp_sizea_r', 'comp_sizeb_r', 'hazard_psy1', 'hazard_psy2', 'hazard_psy3']
#   hazard_erg_a hazard_erg_b  hazard_erg_c  hazard_erg_d  hazard_erg_e  \
# 0          2.0          7.0           1.0           1.0           1.0
# 1          6.0          3.0           2.0           6.0           5.0
# 2          7.0          2.0           2.0           3.0           3.0
# 3          1.0          7.0           1.0           1.0           1.0
# 4          1.0          7.0           1.0           1.0           1.0
#
#    hazard_psy1  hazard_psy2  hazard_psy3
# 0          3.0          4.0          3.0
# 1          4.0          4.0          4.0
# 2          6.0          6.0          6.0
# 3          1.0          1.0          1.0
# 4          1.0          1.0          1.0
# 0    2.0
# 1    6.0
# 2    7.0
# 3    1.0
# 4    1.0
# 5    1.0
# 6    1.0
# 7    1.0
# 8    1.0
# 9    1.0
# Name: hazard_erg_a, dtype: object

# %% [markdown]
# ### 연속형 변수 재범주화

# %%
df['heal_abs1'].value_counts()
# Out:
# heal_abs1
# 0.0      14127
# 2.0        181
# 1.0        127
# 3.0        113
# 5.0         80
# 7.0         65
# 10.0        31
# 8.0         25
# 4.0         24
# 6.0         10
# 15.0         9
# 20.0         6
# 30.0         6
# 14.0         5
# 13.0         5
# 12.0         4
# 90.0         3
# 60.0         2
# 11.0         1
# 180.0        1
# 120.0        1
# 50.0         1
# 21.0         1
# Name: count, dtype: int64

# %%
# 범주화 

df["heal_abs1_group"] = np.where(df["heal_abs1"] == 0, 0, 1)
df['heal_abs1_group'] = df['heal_abs1_group'].map({0: 1, 1: 2})
#%%
print(df["heal_abs1_group"].head())
#%%
df["heal_abs1_group"].value_counts()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: heal_abs1_group, dtype: int64
# heal_abs1_group
# 1    14127
# 2      829
# Name: count, dtype: int64

# %%
# 구간 (0~60, 61~120, 121 이상)
bins = [0, 60, 120, float("inf")]
labels = [1, 2, 3]

df["ctime_group"] = pd.cut(df["ctime"], bins=bins, labels=labels, right=True)
#%%
print(df["ctime_group"].head())
#%%
df["ctime_group"].value_counts()
#%%
# Out:
# 0      1
# 1      1
# 2      1
# 3      2
# 4    NaN
# Name: ctime_group, dtype: category
# Categories (3, int64): [1 < 2 < 3]
# ctime_group
# 1    12582
# 2     1150
# 3      328
# Name: count, dtype: int64

# %%
# 파생변수로 대체된 컬럼 삭제
df = df.drop(['heal_abs1','ctime'], axis = 1)
print(df)
# Out:
#               id burnout60  area  gender  age  wduration_y  earning1  \
# 0      1000042_1       lv1     1       1   49           10       500
# 1      1000051_1       lv2     1       1   31            2       300
# 2      1000056_1       lv1     1       1   32            2       300
# 3      1000069_1       lv1     1       1   38            2       390
# 4      1000069_2       lv1     1       2   37            5       330
# ...          ...       ...   ...     ...  ...          ...       ...
# 14951  2010124_1       lv1     7       1   37            6       450
# 14952  2010133_1       lv2     7       2   46            3       230
# 14953  2010134_2       lv1     7       2   34            5       320
# 14954  2010137_1       lv1     7       1   57            5       450
# 14955  2010137_2       lv1     7       2   29            3       350
#
#        earning2_r  wtime_r  woutside4_a  ...  ind2  occ  occ2  comp_sizea_r  \
# 0               6     40.0            1  ...    46    3   313           4.0
# 1               4     48.0            1  ...    47    3   312          11.0
# 2               4     50.0            1  ...    56    4   441           2.0
# 3               4     40.0            1  ...    42    3   312          10.0
# 4               4     40.0            1  ...    71    2   273           7.0
# ...           ...      ...          ...  ...   ...  ...   ...           ...
# 14951           5     40.0            1  ...    85    2   252           6.0
# 14952           3     40.0            1  ...    52    3   313           4.0
# 14953           4     40.0            1  ...    64    3   320           4.0
# 14954           5     40.0            1  ...    46    5   510           4.0
# 14955           4     40.0            1  ...    61    7   772           4.0
#
#        comp_sizeb_r  hazard_psy1  hazard_psy2  hazard_psy3  heal_abs1_group  \
# 0                 4          3.0          4.0          3.0                1
# 1                11          4.0          4.0          4.0                1
# 2                 2          6.0          6.0          6.0                1
# 3                10          1.0          1.0          1.0                1
# 4                 7          1.0          1.0          1.0                1
# ...             ...          ...          ...          ...              ...
# 14951             6          2.0          2.0          3.0                1
# 14952             4          4.0          3.0          4.0                1
# 14953             4          4.0          3.0          3.0                1
# 14954             4          5.0          3.0          5.0                1
# 14955             4          1.0          2.0          3.0                1
#
#        ctime_group
# 0                1
# 1                1
# 2                1
# 3                2
# 4              NaN
# ...            ...
# 14951            1
# 14952            1
# 14953            1
# 14954            1
# 14955            2
#
# [14956 rows x 221 columns]

# %% [markdown]
# ### 중복 피쳐 삭제

# %%
# 1차 프로젝트에서 파생변수 만들었던 변수 삭제
df = df.drop(['occ', 'occ2', 'age', 'earning2_r', 'wday_week', 'woutside4', 'wtime_r', 'wduration_y'], axis = 1)

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### 상관관계 매트릭스 분석

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = df.corr(numeric_only=True)
# sns.heatmap(corr, cmap="coolwarm", center=0)
# plt.show()

# %%
# 상관계수 절댓값이 0.8 이상인 쌍만 추출 (자기 자신 제외)
high_corr = (
    corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))  
        .stack()                                               
        .reset_index()
        .rename(columns={'level_0': '변수1', 'level_1': '변수2', 0: '상관계수'})
)

# 조건 필터링
high_corr = high_corr[high_corr['상관계수'].abs() >= 0.8]

print(high_corr.sort_values(by='상관계수', ascending=False).head(20))
# Out:
#                     변수1           변수2      상관계수
# 10231       comp_size_b  comp_sizeb_r  1.000000
# 10230       comp_size_b  comp_sizea_r  1.000000
# 15861             disc3         disc4  0.988628
# 21086               ind          ind2  0.985571
# 15758             disc2         disc3  0.984493
# 15759             disc2         disc4  0.982562
# 1804     compsize_group  comp_sizeb_r  0.975227
# 1660     compsize_group   comp_size_b  0.969841
# 15654             disc8         disc2  0.962101
# 15656             disc8         disc4  0.956305
# 15655             disc8         disc3  0.954483
# 15549             disc7         disc8  0.944109
# 15550             disc7         disc2  0.920967
# 21099      comp_sizea_r  comp_sizeb_r  0.920086
# 2195   compsize_group_a  comp_sizeb_r  0.916659
# 15552             disc7         disc4  0.913893
# 15551             disc7         disc3  0.913422
# 1803     compsize_group  comp_sizea_r  0.910546
# 2051   compsize_group_a   comp_size_b  0.893071
# 15443             disc6         disc7  0.886284

# %%
unique_vars = set(high_corr['변수1']).union(set(high_corr['변수2']))
print("조건 충족하는 변수 개수:", len(unique_vars))
print("변수 목록:", unique_vars)
# Out:
# 조건 충족하는 변수 개수: 23
# 변수 목록: {'comp_sizea_r', 'comp_size_b', 'winten2_a', 'disc7', 'woutside_group', 'earning1', 'woutside4_a', 'disc3', 'disc4', 'compsize_group_a', 'decla_a', 'disc2', 'decla_b', 'winten3_c', 'disc6', 'compsize_group', 'ind2', 'disc8', 'comp_sizeb_r', 'earning2_group_b', 'winten3_d', 'winten2_b', 'ind'}

# %%
# 상관분석 결과 필요없는 변수 삭제
df = df.drop(['comp_size_b', 'comp_sizea_r', 'comp_sizeb_r', 'ind', 'ind2', 'earning1', 'woutside4_a'], axis = 1)

# %%
# disc 변수 : 차별 유/무로 파생변수 생성
cols = ['disc1','disc2','disc3','disc4','disc5',
        'disc6','disc7','disc8','disc9','disc10','disc11']

# 하나라도 1이 있으면 1, 아니면 0
df['disc_group'] = (df[cols].sum(axis=1) > 0).astype(int)

df['disc_group'] = df['disc_group'].map({0: 1, 1: 2})

print(df['disc_group'].unique())
# Out:
# [2 1]

# %%
# decla 변수 : 작업선택의 가능성 유/무로 파생변수 생성
cols = ['decla_a','decla_b']

# 하나라도 1이 있으면 1, 아니면 0
df['decla_group'] = (df[cols].sum(axis=1) > 0).astype(int)

df['decla_group'] = df['decla_group'].map({0: 1, 1: 2})

print(df['decla_group'].unique())
# Out:
# [2 1]

# %%
# winten2 변수 : 작업 강도가 세다로 파생변수 생성(7점 척도)
cols = ['winten2_a','winten2_b']

# 둘 중 하나라도 있으면 최대값
df['winten2_group'] = df[cols].max(axis=1, skipna=True)

print(df['winten2_group'].unique())
# Out:
# [ 5.  6.  7.  1.  4.  3.  2. nan]

# %%
# winten3 변수 : 작업선택의 가능성 유/무로 파생변수 생성
cols = ['winten3_c','winten3_d', 'winten3_a', 'winten3_b', 'winten3_e']

# 하나라도 1이 있으면 1, 아니면 0
df['winten3_group'] = (df[cols].sum(axis=1) > 0).astype(int)

df['winten3_group'] = df['winten3_group'].map({0: 1, 1: 2})

print(df['winten3_group'].unique())
# Out:
# [2 1]

# %%
# 파생변수로 대체된 컬럼 삭제
df = df.drop(['disc1','disc2','disc3','disc4','disc5',
              'disc6','disc7','disc8','disc9','disc10','disc11','decla_a','decla_b','winten2_a','winten2_b', 'winten3_c','winten3_d', 'winten3_a', 'winten3_b', 'winten3_e'], axis = 1)

# %% [markdown]
# ### 조작적 정의에 사용된 변수 삭제

# %%
df = df.drop(['weng1','weng2','weng3','wsituation14','wwa2','sleep2','sleep3','weng4','weng5','wsituation1','wstat4','wsituation2','wsituation12', 'wsituation10','wsituation9', 'emp_manaqual_a'], axis = 1)

# %% [markdown]
# ### 모델의 피처 중요도 기반 삭제

# %%
df = df.drop(['sleep1', 'emp_tra_b', 'ch_me', 'emp_winflu_a', 'emp_winflu_b'], axis = 1)

# 'heal_prob1', 'heal_prob2', 'heal_prob3', 'heal_prob4', 'heal_prob5', 'heal_prob6', 'heal_prob8'

# %% [markdown]
# ### 인구 통계 변수 빼고 저장

# %%
df_new = df.drop(['id', 'area', 'gender', 'age_group', 'emp_period_group', 'wtime_group', 'marital', 'children', 'panel_survey', 'edu', 'occ_group_a', 'occ_t2_group_a'], axis = 1)

# %% [markdown]
# ### 널값 삭제

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14956 entries, 0 to 14955
# Columns: 157 entries, burnout60 to winten3_group
# dtypes: category(1), float64(129), int64(24), object(3)
# memory usage: 17.8+ MB

# %%
df_new = df_new.dropna()

# %%
df_new
# Out:
#       burnout60  wtime_length5  compsize_group  woutside_group  \
# 0           lv1              2               4               0
# 1           lv2              2              11               0
# 2           lv1              2               1               0
# 3           lv1              2              10               0
# 5           lv1              2              10               0
# ...         ...            ...             ...             ...
# 14949       lv1              1              12               1
# 14952       lv2              2               4               0
# 14953       lv1              2               4               0
# 14954       lv1              2               4               0
# 14955       lv1              2               4               0
#
#        compsize_group_a  wday_week_group_a  woutside4_group_a  \
# 0                     1                  2                  2
# 1                     3                  2                  2
# 2                     1                  3                  2
# 3                     3                  2                  1
# 5                     3                  2                  3
# ...                 ...                ...                ...
# 14949                 3                  2                  3
# 14952                 1                  2                  3
# 14953                 1                  2                  3
# 14954                 1                  2                  3
# 14955                 1                  2                  3
#
#        earning2_group_b  emp_stat  emp_con_term  ...  income_bal  hazard_psy1  \
# 0                     5         1           2.0  ...         4.0          3.0
# 1                     4         1           2.0  ...         3.0          4.0
# 2                     4         1           2.0  ...         3.0          6.0
# 3                     4         1           2.0  ...         1.0          1.0
# 5                     4         1           1.0  ...         1.0          1.0
# ...                 ...       ...           ...  ...         ...          ...
# 14949                 5         1           2.0  ...         3.0          1.0
# 14952                 3         1           2.0  ...         4.0          4.0
# 14953                 4         1           2.0  ...         3.0          4.0
# 14954                 5         1           2.0  ...         3.0          5.0
# 14955                 4         1           2.0  ...         3.0          1.0
#
#        hazard_psy2  hazard_psy3  heal_abs1_group  ctime_group  disc_group  \
# 0              4.0          3.0                1            1           2
# 1              4.0          4.0                1            1           2
# 2              6.0          6.0                1            1           2
# 3              1.0          1.0                1            2           2
# 5              1.0          1.0                1            1           2
# ...            ...          ...              ...          ...         ...
# 14949          1.0          2.0                1            1           2
# 14952          3.0          4.0                1            1           2
# 14953          3.0          3.0                1            1           2
# 14954          3.0          5.0                1            1           2
# 14955          2.0          3.0                1            2           2
#
#        decla_group  winten2_group  winten3_group
# 0                2            5.0              2
# 1                2            6.0              2
# 2                2            5.0              2
# 3                2            7.0              2
# 5                2            6.0              2
# ...            ...            ...            ...
# 14949            2            4.0              2
# 14952            2            4.0              2
# 14953            2            5.0              2
# 14954            2            5.0              2
# 14955            2            5.0              2
#
# [11344 rows x 157 columns]

# %% [markdown]
# ### 변수 타입 변경

# %%
print(df_new.select_dtypes(include=['object']).columns.tolist())
print(df_new.select_dtypes(include=['category']).columns.tolist())
# Out:
# ['burnout60', 'hazard_erg_a', 'hazard_erg_b']
# ['ctime_group']

# %%
print(df_new.select_dtypes(include=['float64']).columns.tolist())
# Out:
# ['emp_con_term', 'emp_keep', 'emp_own_mgmt', 'emp_fptime', 'emp_wage', 'emp_stat_sp', 'income_pos_a', 'income_pos_b', 'income_pos_c', 'income_pos_d', 'income_pos_e', 'income_pos_f', 'income_pos_g', 'income_pos_h', 'income_pos_i', 'income_pos_j', 'emp_place', 'emp_suggest_a', 'emp_suggest_b', 'emp_manaqual_b', 'emp_manaqual_c', 'emp_manaqual_d', 'emp_manaqual_e', 'emp_comp_ass_a', 'emp_comp_ass_b', 'emp_comp_ass_c', 'emp_comp_ass_d', 'emp_comp_ass_e', 'emp_comp_ass_f', 'emp_rep', 'emp_winflu_c', 'emp_tra_c', 'emp_tra_d', 'wsector', 'comp_female', 'comp_sjob', 'ch_tech', 'ch_ps', 'imte1', 'imte2', 'imte3', 'imte4', 'imte5', 'safeinform', 'wsituation3', 'wsituation4', 'wsituation5', 'wsituation11', 'wsituation6', 'wsituation7', 'wsituation13', 'wstat1', 'wstat2', 'wstat5', 'wstat6', 'wstat7', 'emo_manual', 'asb5', 'asb6', 'asb7', 'wtime_con1', 'wtime_night_a', 'wtime_sun_a', 'wtime_sat_a', 'wtime_long_a', 'wtime_resilience', 'wtime_arr_a', 'wtime_ftwork', 'wtime_private', 'hazard_phy_b', 'hazard_erg_c', 'hazard_erg_d', 'hazard_erg_e', 'winten1_a', 'winten1_b', 'decla_c', 'winterrupt1', 'condim1', 'condim2', 'condim3', 'condim4', 'condim5', 'condim6', 'ass_cust1', 'alter_task1', 'wteam1', 'satisfaction', 'wplace4', 'wplace3', 'wplace2', 'wplace1', 'wpalce_ch', 'wtime_length1', 'wtime_length2', 'wtime_length3', 'wtime_length4', 'job1', 'wbalance', 'wwa1', 'wwa3', 'wwa4', 'wwa5', 'heal_risk', 'heal_wsick1', 'asb1', 'asb2', 'asb3', 'asb4', 'heal_aff', 'heal_cond', 'heal_illhe', 'heal_lim1', 'heal_prob1', 'heal_prob2', 'heal_prob3', 'heal_prob4', 'heal_prob5', 'heal_prob6', 'heal_prob8', 'who1', 'who5', 'woutside3', 'woutside5', 'income_con', 'income_bal', 'hazard_psy1', 'hazard_psy2', 'hazard_psy3', 'winten2_group']

# %%
num_cols = df.select_dtypes(include=['float64']).columns

for col in num_cols:
    min_val, max_val = df[col].min(), df[col].max()
    print(f"{col}: 범위=({min_val}, {max_val})")
# Out:
# emp_con_term: 범위=(1.0, 2.0)
# emp_keep: 범위=(1.0, 2.0)
# emp_own_mgmt: 범위=(1.0, 2.0)
# emp_fptime: 범위=(1.0, 2.0)
# emp_wage: 범위=(1.0, 3.0)
# emp_stat_sp: 범위=(1.0, 2.0)
# income_pos_a: 범위=(1.0, 2.0)
# income_pos_b: 범위=(1.0, 2.0)
# income_pos_c: 범위=(1.0, 2.0)
# income_pos_d: 범위=(1.0, 2.0)
# income_pos_e: 범위=(1.0, 2.0)
# income_pos_f: 범위=(1.0, 2.0)
# income_pos_g: 범위=(1.0, 2.0)
# income_pos_h: 범위=(1.0, 2.0)
# income_pos_i: 범위=(1.0, 2.0)
# income_pos_j: 범위=(1.0, 2.0)
# emp_place: 범위=(1.0, 2.0)
# emp_suggest_a: 범위=(1.0, 2.0)
# emp_suggest_b: 범위=(1.0, 2.0)
# emp_manaqual_b: 범위=(1.0, 5.0)
# emp_manaqual_c: 범위=(1.0, 5.0)
# emp_manaqual_d: 범위=(1.0, 5.0)
# emp_manaqual_e: 범위=(1.0, 5.0)
# emp_comp_ass_a: 범위=(1.0, 5.0)
# emp_comp_ass_b: 범위=(1.0, 5.0)
# emp_comp_ass_c: 범위=(1.0, 5.0)
# emp_comp_ass_d: 범위=(1.0, 5.0)
# emp_comp_ass_e: 범위=(1.0, 5.0)
# emp_comp_ass_f: 범위=(1.0, 5.0)
# emp_rep: 범위=(1.0, 3.0)
# emp_winflu_c: 범위=(1.0, 7.0)
# emp_tra_c: 범위=(1.0, 2.0)
# emp_tra_d: 범위=(1.0, 2.0)
# wsector: 범위=(1.0, 4.0)
# comp_female: 범위=(1.0, 3.0)
# comp_sjob: 범위=(1.0, 4.0)
# ch_tech: 범위=(1.0, 2.0)
# ch_ps: 범위=(1.0, 2.0)
# imte1: 범위=(1.0, 4.0)
# imte2: 범위=(1.0, 4.0)
# imte3: 범위=(1.0, 4.0)
# imte4: 범위=(1.0, 4.0)
# imte5: 범위=(1.0, 4.0)
# safeinform: 범위=(1.0, 4.0)
# wsituation3: 범위=(1.0, 7.0)
# wsituation4: 범위=(1.0, 7.0)
# wsituation5: 범위=(1.0, 7.0)
# wsituation11: 범위=(1.0, 5.0)
# wsituation6: 범위=(1.0, 5.0)
# wsituation7: 범위=(1.0, 5.0)
# wsituation13: 범위=(1.0, 5.0)
# wstat1: 범위=(1.0, 7.0)
# wstat2: 범위=(1.0, 7.0)
# wstat5: 범위=(1.0, 7.0)
# wstat6: 범위=(1.0, 7.0)
# wstat7: 범위=(1.0, 7.0)
# emo_manual: 범위=(1.0, 2.0)
# asb5: 범위=(1.0, 2.0)
# asb6: 범위=(1.0, 2.0)
# asb7: 범위=(1.0, 2.0)
# wtime_con1: 범위=(1.0, 2.0)
# wtime_night_a: 범위=(0.0, 1.0)
# wtime_sun_a: 범위=(0.0, 1.0)
# wtime_sat_a: 범위=(0.0, 1.0)
# wtime_long_a: 범위=(0.0, 1.0)
# wtime_resilience: 범위=(2.0, 2.0)
# wtime_arr_a: 범위=(1.0, 4.0)
# wtime_ftwork: 범위=(1.0, 5.0)
# wtime_private: 범위=(1.0, 4.0)
# hazard_phy_b: 범위=(1.0, 7.0)
# hazard_erg_c: 범위=(1.0, 7.0)
# hazard_erg_d: 범위=(1.0, 7.0)
# hazard_erg_e: 범위=(1.0, 7.0)
# winten1_a: 범위=(1.0, 2.0)
# winten1_b: 범위=(1.0, 2.0)
# decla_c: 범위=(1.0, 2.0)
# winterrupt1: 범위=(1.0, 4.0)
# condim1: 범위=(1.0, 2.0)
# condim2: 범위=(1.0, 2.0)
# condim3: 범위=(1.0, 2.0)
# condim4: 범위=(1.0, 2.0)
# condim5: 범위=(1.0, 2.0)
# condim6: 범위=(1.0, 2.0)
# ass_cust1: 범위=(1.0, 2.0)
# alter_task1: 범위=(1.0, 2.0)
# wteam1: 범위=(1.0, 2.0)
# satisfaction: 범위=(1.0, 4.0)
# wplace4: 범위=(1.0, 5.0)
# wplace3: 범위=(1.0, 5.0)
# wplace2: 범위=(1.0, 5.0)
# wplace1: 범위=(1.0, 5.0)
# wpalce_ch: 범위=(1.0, 4.0)
# wtime_length1: 범위=(1.0, 2.0)
# wtime_length2: 범위=(1.0, 2.0)
# wtime_length3: 범위=(1.0, 2.0)
# wtime_length4: 범위=(1.0, 2.0)
# job1: 범위=(1.0, 2.0)
# wbalance: 범위=(1.0, 4.0)
# wwa1: 범위=(1.0, 7.0)
# wwa3: 범위=(1.0, 7.0)
# wwa4: 범위=(1.0, 7.0)
# wwa5: 범위=(1.0, 7.0)
# heal_risk: 범위=(1.0, 2.0)
# heal_wsick1: 범위=(1.0, 2.0)
# asb1: 범위=(1.0, 2.0)
# asb2: 범위=(1.0, 2.0)
# asb3: 범위=(1.0, 2.0)
# asb4: 범위=(1.0, 2.0)
# heal_aff: 범위=(1.0, 3.0)
# heal_cond: 범위=(1.0, 5.0)
# heal_illhe: 범위=(1.0, 2.0)
# heal_lim1: 범위=(1.0, 3.0)
# heal_prob1: 범위=(1.0, 2.0)
# heal_prob2: 범위=(1.0, 2.0)
# heal_prob3: 범위=(1.0, 2.0)
# heal_prob4: 범위=(1.0, 2.0)
# heal_prob5: 범위=(1.0, 2.0)
# heal_prob6: 범위=(1.0, 2.0)
# heal_prob8: 범위=(1.0, 2.0)
# who1: 범위=(1.0, 6.0)
# who5: 범위=(1.0, 6.0)
# woutside3: 범위=(1.0, 5.0)
# woutside5: 범위=(1.0, 5.0)
# income_con: 범위=(1.0, 3.0)
# income_bal: 범위=(1.0, 6.0)
# edu: 범위=(1.0, 7.0)
# marital: 범위=(1.0, 2.0)
# children: 범위=(1.0, 2.0)
# hazard_psy1: 범위=(1.0, 9.0)
# hazard_psy2: 범위=(1.0, 9.0)
# hazard_psy3: 범위=(1.0, 9.0)
# winten2_group: 범위=(1.0, 7.0)

# %%
# 데이터 타입 변경
df_new['hazard_erg_a'] = df_new['hazard_erg_a'].astype('int64')
df_new['hazard_erg_b'] = df_new['hazard_erg_b'].astype('int64')
df_new['ctime_group'] = df_new['ctime_group'].astype('int64')
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11344 entries, 0 to 14955
# Columns: 157 entries, burnout60 to winten3_group
# dtypes: float64(129), int64(27), object(1)
# memory usage: 13.7+ MB

# %%
# 타겟 클래스번호 전처리
df_new['burnout60'] = df_new['burnout60'].replace("lv1", 1)
df_new['burnout60'] = df_new['burnout60'].replace("lv2", 2)
df_new['burnout60'] = df_new['burnout60'].replace("lv3", 3)
df_new['burnout60'].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
df_new['burnout60'] = df_new['burnout60'].astype('int64')

# %%
df_new['burnout60'] = df_new['burnout60'] - 1

# %%
df_new['burnout60'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11344 entries, 0 to 14955
# Columns: 157 entries, burnout60 to winten3_group
# dtypes: float64(129), int64(28)
# memory usage: 13.7 MB

# %% [markdown]
# ## 모델 적용

# %% [markdown]
# ### 1차 모델 - multiclass(LGBM)

# %%
# 클래스 분포 확인
print(df_new['burnout60'].value_counts())
print("번아웃클래스 이진으로 분류한다면: ", df_new['burnout60'].value_counts().iloc[1:].sum(), "명")
# Out:
# burnout60
# 0    9704
# 1    1424
# 2     216
# Name: count, dtype: int64
# 번아웃클래스 이진으로 분류한다면:  1640 명

# %%
# 학습(훈련) 데이터
train_X = df_new.drop(['burnout60'], axis = 1)
train_Y = df_new["burnout60"]

print("train_X 데이터: ", train_X.shape)
print("train_Y 데이터: ", train_Y.shape)
# Out:
# train_X 데이터:  (11344, 156)
# train_Y 데이터:  (11344,)

# %%
from sklearn.model_selection import train_test_split

# 1차 분할: Train (80%) vs Test (20%)
X_train, X_test, y_train, y_test = train_test_split(
    train_X, train_Y, test_size=0.2, random_state=42, stratify=train_Y
)

# 2차 분할: Train 내부에서 다시 Train (80%) vs Validation (20%)
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42, stratify=y_train
)

print("Train shape:", X_train.shape, y_train.shape)
print("Validation shape:", X_val.shape, y_val.shape)
print("Test shape:", X_test.shape, y_test.shape)
# Out:
# Train shape: (7260, 156) (7260,)
# Validation shape: (1815, 156) (1815,)
# Test shape: (2269, 156) (2269,)

# %%
print("Train 클래스 분포:")
print(y_train.value_counts())               
print(y_train.value_counts(normalize=True))
# Out:
# Train 클래스 분포:
# burnout60
# 0    6210
# 1     911
# 2     139
# Name: count, dtype: int64
# burnout60
# 0    0.855372
# 1    0.125482
# 2    0.019146
# Name: proportion, dtype: float64

# %%
print("val 클래스 분포:")
print(y_val.value_counts())
print(y_val.value_counts(normalize=True))
# Out:
# val 클래스 분포:
# burnout60
# 0    1553
# 1     228
# 2      34
# Name: count, dtype: int64
# burnout60
# 0    0.855647
# 1    0.125620
# 2    0.018733
# Name: proportion, dtype: float64

# %%
print("Test 클래스 분포:")
print(y_test.value_counts())
print(y_test.value_counts(normalize=True))
# Out:
# Test 클래스 분포:
# burnout60
# 0    1941
# 1     285
# 2      43
# Name: count, dtype: int64
# burnout60
# 0    0.855443
# 1    0.125606
# 2    0.018951
# Name: proportion, dtype: float64

# %%
# 스케일링
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled   = scaler.transform(X_val)
X_test_scaled  = scaler.transform(X_test)

# %%
# SMOTE
from imblearn.combine import SMOTEENN
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42, k_neighbors=3)
smote_enn = SMOTEENN(random_state=42, smote=smote)

X_train_res, y_train_res = smote_enn.fit_resample(X_train_scaled, y_train)
print("After SMOTE-ENN:", pd.Series(y_train_res).value_counts())
# Out:
# c:\Users\user\anaconda3\envs\python310\lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] 지정된 파일을 찾을 수 없습니다
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\user\anaconda3\envs\python310\lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#   File "c:\Users\user\anaconda3\envs\python310\lib\subprocess.py", line 503, in run
#     with Popen(*popenargs, **kwargs) as process:
#   File "c:\Users\user\anaconda3\envs\python310\lib\subprocess.py", line 971, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "c:\Users\user\anaconda3\envs\python310\lib\subprocess.py", line 1456, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
# After SMOTE-ENN: burnout60
# 2    6210
# 1    6164
# 0    2710
# Name: count, dtype: int64

# %%
from sklearn.metrics import f1_score
from lightgbm import LGBMClassifier, early_stopping, log_evaluation
import optuna

def objective(trial):
    params = {
        'objective': 'multiclass',
        'metric': 'multi_logloss',
        'num_class': 3,
        'boosting_type': 'gbdt',
        "class_weight": "balanced",
        'num_leaves': trial.suggest_int('num_leaves', 10, 100),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
        'feature_fraction': trial.suggest_uniform('feature_fraction', 0.1, 1.0),
        'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.1, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 10),
        'reg_alpha': trial.suggest_float('lgbm_reg_alpha', 1e-8, 1e-1, log=True),
        'reg_lambda': trial.suggest_float('lgbm_reg_lambda', 1e-8, 1e-1, log=True),
        # "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        # "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        'random_state': 42,
        'verbosity': -1
    }

    model = LGBMClassifier(**params)
    model.fit(
        X_train_res, y_train_res,
        eval_set=[(X_val_scaled, y_val)],
        callbacks=[early_stopping(50), log_evaluation(0)]
    )

    y_pred = model.predict(X_val_scaled)
    f1_class2 = f1_score(y_val, y_pred, average=None, labels=[0,1,2])[2]
    return f1_class2

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)

best_params = study.best_trial.params
print("Best Params:", best_params)
# Out:
# [I 2025-09-02 16:48:45,427] A new study created in memory with name: no-name-deec3059-51b2-4347-bace-8c33954725f8
# Training until validation scores don't improve for 50 rounds
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.1, 1.0),
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.1, 1.0),
# [I 2025-09-02 16:48:45,934] Trial 0 finished with value: 0.3870967741935484 and parameters: {'num_leaves': 22, 'learning_rate': 0.03384396970451732, 'feature_fraction': 0.6935713553041949, 'bagging_fraction': 0.5548100007128378, 'bagging_freq': 10, 'lgbm_reg_alpha': 0.0028339930738156198, 'lgbm_reg_lambda': 2.1460909271865978e-08}. Best is trial 0 with value: 0.3870967741935484.
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's multi_logloss: 0.403661
# Training until validation scores don't improve for 50 rounds
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.1, 1.0),
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.1, 1.0),
# [I 2025-09-02 16:48:46,300] Trial 1 finished with value: 0.4444444444444444 and parameters: {'num_leaves': 29, 'learning_rate': 0.013506909558371813, 'feature_fraction': 0.13524136898461092, 'bagging_fraction': 0.18483595560214064, 'bagging_freq': 3, 'lgbm_reg_alpha': 2.4476210156455393e-05, 'lgbm_reg_lambda': 2.5196388051237608e-05}. Best is trial 1 with value: 0.4444444444444444.
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's multi_logloss: 0.540573
# Training until validation scores don't improve for 50 rounds
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.1, 1.0),
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.1, 1.0),
# [I 2025-09-02 16:48:47,183] Trial 2 finished with value: 0.35294117647058826 and parameters: {'num_leaves': 44, 'learning_rate': 0.0129697573382942, 'feature_fraction': 0.9122101282940093, 'bagging_fraction': 0.6640254008528795, 'bagging_freq': 5, 'lgbm_reg_alpha': 3.9682567136649475e-07, 'lgbm_reg_lambda': 0.003931654490527377}. Best is trial 1 with value: 0.4444444444444444.
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's multi_logloss: 0.522216
# Training until validation scores don't improve for 50 rounds
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.1, 1.0),
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.1, 1.0),
# [I 2025-09-02 16:48:47,714] Trial 3 finished with value: 0.39436619718309857 and parameters: {'num_leaves': 26, 'learning_rate': 0.026044997479850306, 'feature_fraction': 0.9295758135219321, 'bagging_fraction': 0.3732486944534885, 'bagging_freq': 9, 'lgbm_reg_alpha': 4.037557384444695e-05, 'lgbm_reg_lambda': 3.778870046438189e-07}. Best is trial 1 with value: 0.4444444444444444.
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's multi_logloss: 0.432731
# Training until validation scores don't improve for 50 rounds
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.1, 1.0),
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.1, 1.0),
# [I 2025-09-02 16:48
# Training until validation scores don't improve for 50 rounds
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.1, 1.0),
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.1, 1.0),
# [I 2025-09-02 16:49:39,619] Trial 98 finished with value: 0.4666666666666667 and parameters: {'num_leaves': 36, 'learning_rate': 0.01313017785428773, 'feature_fraction': 0.23410237351803495, 'bagging_fraction': 0.6210834843177204, 'bagging_freq': 9, 'lgbm_reg_alpha': 1.5552820197850484e-08, 'lgbm_reg_lambda': 5.830602747953388e-06}. Best is trial 64 with value: 0.5217391304347826.
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's multi_logloss: 0.515649
# Training until validation scores don't improve for 50 rounds
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:14: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.1, 1.0),
# C:\Users\user\AppData\Local\Temp\ipykernel_16364\1415051308.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.1, 1.0),
# [I 2025-09-02 16:49:40,003] Trial 99 finished with value: 0.43037974683544306 and parameters: {'num_leaves': 15, 'learning_rate': 0.01473215618755668, 'feature_fraction': 0.28875117908842884, 'bagging_fraction': 0.6451155178563911, 'bagging_freq': 8, 'lgbm_reg_alpha': 5.89665380792693e-08, 'lgbm_reg_lambda': 3.2474677069736404e-06}. Best is trial 64 with value: 0.5217391304347826.
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's multi_logloss: 0.527913
# Best Params: {'num_leaves': 19, 'learning_rate': 0.02053400784919012, 'feature_fraction': 0.15537130463227172, 'bagging_fraction': 0.199489881579102, 'bagging_freq': 10, 'lgbm_reg_alpha': 6.011447761770446e-07, 'lgbm_reg_lambda': 3.541359421390768e-06}

# %% [markdown]
# #### 모델 적용(multiclass)(LGBM)

# %%
best_model = LGBMClassifier(
    **best_params,
    objective="multiclass",
    num_class=3,
    random_state=42
)
best_model.fit(X_train_res, y_train_res)
# Out:
# LGBMClassifier(bagging_fraction=0.199489881579102, bagging_freq=10,
#                feature_fraction=0.15537130463227172,
#                learning_rate=0.02053400784919012,
#                lgbm_reg_alpha=6.011447761770446e-07,
#                lgbm_reg_lambda=3.541359421390768e-06, num_class=3,
#                num_leaves=19, objective='multiclass', random_state=42)

# %%
from sklearn.metrics import precision_recall_curve

y_proba_val = best_model.predict_proba(X_val_scaled)
y_true_bin = (y_val == 2).astype(int)  # 클래스 2 vs 나머지

prec, rec, thresh = precision_recall_curve(y_true_bin, y_proba_val[:, 2])
f1_scores = 2 * (prec * rec) / (prec + rec + 1e-8)
best_idx = np.argmax(f1_scores)
best_thresh = thresh[best_idx]

print("Best Threshold for class 2:", best_thresh)
print("Precision:", prec[best_idx], "Recall:", rec[best_idx], "F1:", f1_scores[best_idx])
# Out:
# Best Threshold for class 2: 0.41582954701779734
# Precision: 0.5 Recall: 0.5 F1: 0.4999999950000001

# %%
y_pred_val = []
for p in y_proba_val:
    if p[2] > best_thresh:     # 클래스 2 기준 threshold 적용
        y_pred_val.append(2)
    else:
        y_pred_val.append(np.argmax(p[:2]))  # 클래스 0/1 중 높은 확률 선택
y_pred_val = np.array(y_pred_val)

print("\n=== Validation Report with threshold tuning ===")
print(classification_report(y_val, y_pred_val))
# Out:
# === Validation Report with threshold tuning ===
#               precision    recall  f1-score   support
#
#            0       0.95      0.78      0.86      1553
#            1       0.30      0.66      0.41       228
#            2       0.48      0.47      0.48        34
#
#     accuracy                           0.76      1815
#    macro avg       0.58      0.64      0.58      1815
# weighted avg       0.86      0.76      0.79      1815

# %% [markdown]
# #### feature importance 시각화

# %%
# feature importance (gain 기준)
importance = pd.DataFrame(best_model.booster_.feature_importance(importance_type='gain'), index=X_train.columns, columns=["importance"]).sort_values(by="importance",ascending = True).tail(20)
importance

# 변수중요도 비율로 전환
importance['importance_pct'] = importance['importance'] / importance['importance'].sum() * 100
importance.head(20)
# Out:
#                  importance  importance_pct
# who4            1223.191018        1.702304
# wstat3          1496.271307        2.082348
# emp_comp_ass_f  1565.122603        2.178167
# wwa3            1679.958092        2.337983
# wstat1          1924.293401        2.678022
# who5            1975.439314        2.749202
# emp_comp_ass_b  2174.557119        3.026312
# who3            2437.867610        3.392759
# wsituation6     2514.898090        3.499962
# wsituation13    3070.540518        4.273244
# who2            3220.863609        4.482448
# emp_comp_ass_a  3276.998482        4.560570
# wstat2          4069.042727        5.662851
# wsituation4     4127.648865        5.744413
# who1            4189.714968        5.830790
# wstat5          4355.543245        6.061571
# wsituation7     5545.573880        7.717727
# wsituation3     6972.868716        9.704080
# wsituation11    6990.499539        9.728617
# wsituation8     9044.124185       12.586629

# %%
importance['importance_pct'].plot.barh()
plt.show()

# %% [markdown]
# #### Shap 클래스2(번아웃 진단군) 변수 중요도 확인

# %%
# LightGBM 모델 학습된 객체: best_model
explainer = shap.TreeExplainer(best_model)

# %%
# SHAP 값 (Explanation 객체)
shap_values = explainer(X_train_res)
shap_values_class2 = shap_values[:,:,2]

# SHAP 절댓값 평균으로 변수 중요도 계산
shap_importance = np.abs(shap_values_class2.values).mean(axis=0)

fi_shap = pd.DataFrame({
    'feature': X_train.columns,
    'importance_shap': shap_importance
}).sort_values(by='importance_shap', ascending=False).reset_index(drop=True)

print(fi_shap.head(20))
# Out:
#            feature  importance_shap
# 0      wsituation8         0.101762
# 1     wsituation11         0.099218
# 2      wsituation3         0.092431
# 3      wsituation7         0.091700
# 4      wsituation4         0.086264
# 5             who2         0.068376
# 6      wsituation6         0.064236
# 7             who1         0.063031
# 8     wsituation13         0.051615
# 9             who3         0.048155
# 10  emp_comp_ass_b         0.045154
# 11            wwa3         0.040873
# 12          wstat2         0.038694
# 13          wstat1         0.034930
# 14      safeinform         0.032594
# 15            who5         0.031240
# 16           imte3         0.027453
# 17          wstat5         0.026176
# 18          wstat7         0.024130
# 19            who4         0.022742

# %%
# 변수 이름 저장
top_features = fi_shap['feature'].head(50).tolist()

X_top = X_train[top_features]
X_top
# Out:
#        wsituation8  wsituation11  wsituation3  wsituation7  wsituation4  who2  \
# 9765             2           2.0          1.0          1.0          2.0     3
# 4450             2           3.0          3.0          3.0          3.0     5
# 14306            2           2.0          1.0          1.0          2.0     2
# 5979             3           4.0          3.0          2.0          2.0     2
# 622              2           3.0          2.0          2.0          2.0     2
# ...            ...           ...          ...          ...          ...   ...
# 5892             3           3.0          3.0          2.0          2.0     2
# 4703             3           3.0          2.0          2.0          3.0     3
# 11564            3           2.0          3.0          3.0          3.0     1
# 11174            3           3.0          2.0          3.0          2.0     2
# 5679             4           4.0          3.0          3.0          4.0     2
#
#        wsituation6  who1  wsituation13  who3  ...  wsituation5  imte2  \
# 9765           2.0   3.0           2.0     4  ...          3.0    1.0
# 4450           3.0   5.0           4.0     5  ...          3.0    4.0
# 14306          2.0   3.0           2.0     2  ...          4.0    2.0
# 5979           3.0   3.0           3.0     3  ...          3.0    4.0
# 622            3.0   2.0           3.0     2  ...          2.0    3.0
# ...            ...   ...           ...   ...  ...          ...    ...
# 5892           2.0   1.0           3.0     1  ...          3.0    3.0
# 4703           3.0   2.0           2.0     2  ...          2.0    2.0
# 11564          4.0   2.0           4.0     2  ...          3.0    2.0
# 11174          2.0   2.0           4.0     2  ...          2.0    3.0
# 5679           3.0   2.0           3.0     5  ...          4.0    3.0
#
#        hazard_erg_d  hazard_psy2  heal_prob2  emp_manaqual_b  emp_con_term  \
# 9765            1.0          1.0         1.0             1.0           2.0
# 4450            3.0          2.0         1.0             2.0           2.0
# 14306           4.0          2.0         1.0             2.0           2.0
# 5979            3.0          5.0         2.0             2.0           2.0
# 622             5.0          1.0         2.0             1.0           2.0
# ...             ...          ...         ...             ...           ...
# 5892            2.0          2.0         1.0             2.0           2.0
# 4703            1.0          1.0         1.0             2.0           2.0
# 11564           1.0          3.0         1.0             1.0           2.0
# 11174           3.0          2.0         1.0             2.0           2.0
# 5679            1.0          2.0         1.0             3.0           2.0
#
#        emp_boss_gender  heal_prob1  emp_manaqual_e
# 9765                 1         2.0             2.0
# 4450                 1         2.0             2.0
# 14306                1         2.0             2.0
# 5979                 2         1.0             2.0
# 622                  2         1.0             2.0
# ...                ...         ...             ...
# 5892                 1         2.0             2.0
# 4703                 1         2.0             3.0
# 11564                1         2.0             2.0
# 11174                1         2.0             3.0
# 5679                 2         2.0             3.0
#
# [7260 rows x 50 columns]

# %%
# summary plot
shap.summary_plot(
    shap_values_class2,
    X_train_res,
    feature_names=X_train.columns  
)

# %% [markdown]
# ### 2차 모델 - 변수 선택 50개(클래스2 중요도 기반)

# %%
X_train_top = X_train[top_features]
X_val_top   = X_val[top_features]
X_test_top  = X_test[top_features]

print("Train shape:", X_train_top.shape)
print("Train shape:", X_val_top.shape)
# Out:
# Train shape: (7260, 50)
# Train shape: (1815, 50)

# %%
scaler = MinMaxScaler()
X_train_top_scaled = scaler.fit_transform(X_train_top)
X_val_top_scaled   = scaler.transform(X_val_top)
X_test_top_scaled  = scaler.transform(X_test_top)

# %%
smote = SMOTE(random_state=42, k_neighbors=3)
smote_enn = SMOTEENN(random_state=42, smote=smote)
X_train_res, y_train_res = smote_enn.fit_resample(X_train_top_scaled, y_train)

print("Resampled class distribution:\n", pd.Series(y_train_res).value_counts())
# Out:
# Resampled class distribution:
#  burnout60
# 2    6210
# 1    6163
# 0    3781
# Name: count, dtype: int64

# %%
model_top = LGBMClassifier(
    **best_params,        # Optuna에서 찾은 최적 파라미터 쓰는 게 좋음
    objective="multiclass",
    num_class=3,
    random_state=42
)

model_top.fit(
    X_train_res, y_train_res,
    eval_set=[(X_val_top_scaled, y_val)],
    callbacks=[early_stopping(50), log_evaluation(1)]
)
# Out:
# [1]	valid_0's multi_logloss: 1.35563
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0
# [74]	valid_0's multi_logloss: 0.614826
# [75]	valid_0's multi_logloss: 0.610697
# [76]	valid_0's multi_logloss: 0.60653
# [77]	valid_0's multi_logloss: 0.602663
# [78]	valid_0's multi_logloss: 0.598964
# [79]	valid_0's multi_logloss: 0.595701
# [80]	valid_0's multi_logloss: 0.592326
# [81]	valid_0's multi_logloss: 0.589598
# [82]	valid_0's multi_logloss: 0.586748
# [83]	valid_0's multi_logloss: 0.583699
# [84]	valid_0's multi_logloss: 0.5808
# [85]	valid_0's multi_logloss: 0.578274
# [86]	valid_0's multi_logloss: 0.575048
# [87]	valid_0's multi_logloss: 0.571895
# [88]	valid_0's multi_logloss: 0.569125
# [89]	valid_0's multi_logloss: 0.566937
# [90]	valid_0's multi_logloss: 0.564376
# [91]	valid_0's multi_logloss: 0.562127
# [92]	valid_0's multi_logloss: 0.559684
# [93]	valid_0's multi_logloss: 0.557012
# [94]	valid_0's multi_logloss: 0.554557
# [95]	valid_0's multi_logloss: 0.552487
# [96]	valid_0's multi_logloss: 0.550194
# [97]	valid_0's multi_logloss: 0.547842
# [98]	valid_0's multi_logloss: 0.545821
# [99]	valid_0's multi_logloss: 0.543868
# [100]	valid_0's multi_logloss: 0.541865
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's multi_logloss: 0.541865
# LGBMClassifier(bagging_fraction=0.199489881579102, bagging_freq=10,
#                feature_fraction=0.15537130463227172,
#                learning_rate=0.02053400784919012,
#                lgbm_reg_alpha=6.011447761770446e-07,
#                lgbm_reg_lambda=3.541359421390768e-06, num_class=3,
#                num_leaves=19, objective='multiclass', random_state=42)

# %%
y_proba_val = model_top.predict_proba(X_val_top_scaled)
y_true_bin = (y_val == 2).astype(int)

prec, rec, thresh = precision_recall_curve(y_true_bin, y_proba_val[:, 2])
f1_scores = 2 * (prec * rec) / (prec + rec + 1e-8)
best_idx = np.argmax(f1_scores)
best_thresh = thresh[best_idx]

print("Best Threshold for class 2:", best_thresh)
print("Precision:", prec[best_idx], "Recall:", rec[best_idx], "F1:", f1_scores[best_idx])
# Out:
# Best Threshold for class 2: 0.4117028388953168
# Precision: 0.4418604651162791 Recall: 0.5588235294117647 F1: 0.4935064885748019

# %%
y_pred_val = []
for p in y_proba_val:
    if p[2] > best_thresh:     # 클래스 2 기준 threshold 적용
        y_pred_val.append(2)
    else:
        y_pred_val.append(np.argmax(p[:2]))  # 클래스 0/1 중 높은 확률 선택
y_pred_val = np.array(y_pred_val)

print("\n=== Validation Report with threshold tuning ===")
print(classification_report(y_val, y_pred_val))
# Out:
# === Validation Report with threshold tuning ===
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.89      1553
#            1       0.31      0.45      0.37       228
#            2       0.43      0.53      0.47        34
#
#     accuracy                           0.80      1815
#    macro avg       0.55      0.61      0.58      1815
# weighted avg       0.84      0.80      0.81      1815

# %% [markdown]
# ### 3차 모델 - 이진분류

# %%
# 1, 2 클래스 결합
df_new['burnout60'] = df_new['burnout60'].replace(2, 1)

print(df_new['burnout60'].value_counts())
print("번아웃클래스 이진 분류: ", df_new['burnout60'].value_counts().iloc[1:].sum(), "명")
# Out:
# burnout60
# 0    9704
# 1    1640
# Name: count, dtype: int64
# 번아웃클래스 이진 분류:  1640 명

# %%
# 학습(훈련) 데이터
train_X = df_new.drop(['burnout60'], axis = 1)
train_Y = df_new["burnout60"]

print("train_X 데이터: ", train_X.shape)
print("train_Y 데이터: ", train_Y.shape)
# Out:
# train_X 데이터:  (11344, 156)
# train_Y 데이터:  (11344,)

# %%
# 검증데이터 나누기
from sklearn.model_selection import train_test_split

# 1차 분할: Train (80%) vs Test (20%)
X_train, X_test, y_train, y_test = train_test_split(
    train_X, train_Y, test_size=0.2, random_state=42, stratify=train_Y
)

# 2차 분할: Train 내부에서 다시 Train (80%) vs Validation (20%)
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42, stratify=y_train
)

print("Train shape:", X_train.shape, y_train.shape)
print("Validation shape:", X_val.shape, y_val.shape)
print("Test shape:", X_test.shape, y_test.shape)
# Out:
# Train shape: (7260, 156) (7260,)
# Validation shape: (1815, 156) (1815,)
# Test shape: (2269, 156) (2269,)

# %%
# 스케일링
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled   = scaler.transform(X_val)
X_test_scaled  = scaler.transform(X_test)

# %%
# SMOTE
from imblearn.combine import SMOTEENN
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42, k_neighbors=3)
smote_enn = SMOTEENN(random_state=42, smote=smote)

X_train_res, y_train_res = smote_enn.fit_resample(X_train_scaled, y_train)
print("After SMOTE-ENN:", pd.Series(y_train_res).value_counts())
# Out:
# c:\Users\user\anaconda3\envs\python310\lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] 지정된 파일을 찾을 수 없습니다
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\user\anaconda3\envs\python310\lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#   File "c:\Users\user\anaconda3\envs\python310\lib\subprocess.py", line 503, in run
#     with Popen(*popenargs, **kwargs) as process:
#   File "c:\Users\user\anaconda3\envs\python310\lib\subprocess.py", line 971, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "c:\Users\user\anaconda3\envs\python310\lib\subprocess.py", line 1456, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
# After SMOTE-ENN: burnout60
# 1    6152
# 0    2824
# Name: count, dtype: int64

# %%
from sklearn.metrics import f1_score
from lightgbm import LGBMClassifier, early_stopping, log_evaluation
from sklearn.model_selection import StratifiedKFold
import optuna

def objective(trial):
    params = {
        "objective": "binary",
        "metric": "binary_logloss",
        "boosting_type": "gbdt",
        "class_weight": "balanced",
        "n_estimators": trial.suggest_int("n_estimators", 300, 1200, step=100),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 2e-1, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 31, 255, step=8),
        "max_depth": trial.suggest_int("max_depth", -1, 16),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 60, step=5),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 1e-1, log=True),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-8, 1e-1, log=True),
        "random_state": 42,
        "verbosity": -1
    }

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    f1_scores = []

    for tr_idx, val_idx in skf.split(X_train_res, y_train_res):
        X_tr, X_val_fold = X_train_res[tr_idx], X_train_res[val_idx]
        y_tr, y_val_fold = y_train_res[tr_idx], y_train_res[val_idx]

        model = LGBMClassifier(**params)
        model.fit(X_tr, y_tr)

        y_pred = model.predict(X_val_fold)
        f1 = f1_score(y_val_fold, y_pred)
        f1_scores.append(f1)

    return np.mean(f1_scores)

# --------------------------
# 3. Optuna 실행
# --------------------------
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)

best_params = study.best_trial.params
print("Best Params:", best_params)
# Out:
# [I 2025-09-03 10:08:06,307] A new study created in memory with name: no-name-ba3e5efd-8081-466f-b66c-7a0978b758f5
# [I 2025-09-03 10:08:07,573] Trial 0 finished with value: 0.9560279961050361 and parameters: {'n_estimators': 600, 'learning_rate': 0.02106787361027207, 'num_leaves': 103, 'max_depth': 2, 'min_child_samples': 40, 'subsample': 0.8091397959416423, 'colsample_bytree': 0.9428144970867092, 'reg_alpha': 2.739567338725627e-08, 'reg_lambda': 0.0005247771316412359}. Best is trial 0 with value: 0.9560279961050361.
# [I 2025-09-03 10:08:11,944] Trial 1 finished with value: 0.9455873146384883 and parameters: {'n_estimators': 300, 'learning_rate': 0.0025388240509665793, 'num_leaves': 87, 'max_depth': 16, 'min_child_samples': 60, 'subsample': 0.8653522212282992, 'colsample_bytree': 0.8713734206713117, 'reg_alpha': 2.1435133173994114e-06, 'reg_lambda': 0.010418908564998941}. Best is trial 0 with value: 0.9560279961050361.
# [I 2025-09-03 10:08:13,156] Trial 2 finished with value: 0.9276828952103688 and parameters: {'n_estimators': 400, 'learning_rate': 0.0014766317057031781, 'num_leaves': 39, 'max_depth': 3, 'min_child_samples': 40, 'subsample': 0.8430548101038862, 'colsample_bytree': 0.8891980739414423, 'reg_alpha': 1.8524271639195244e-07, 'reg_lambda': 9.037712610383028e-07}. Best is trial 0 with value: 0.9560279961050361.
# [I 2025-09-03 10:08:24,944] Trial 3 finished with value: 0.9700376665105622 and parameters: {'n_estimators': 1100, 'learning_rate': 0.034692900329729125, 'num_leaves': 255, 'max_depth': 10, 'min_child_samples': 40, 'subsample': 0.8402010174371816, 'colsample_bytree': 0.8935927725237359, 'reg_alpha': 0.018420566891030984, 'reg_lambda': 0.0003350354791386213}. Best is trial 3 with value: 0.9700376665105622.
# [I 2025-09-03 10:08:40,948] Trial 4 finished with value: 0.9688347755865445 and parameters: {'n_estimators': 700, 'learning_rate': 0.01402805953904785, 'num_leaves': 223, 'max_depth': 12, 'min_child_samples': 20, 'subsample': 0.6893288350038687, 'colsample_bytree': 0.8251779354238541, 'reg_alpha': 0.0228657152175667, 'reg_lambda': 0.00422218165576153}. Best is trial 3 with value: 0.9700376665105622.
# [I 2025-09-03 10:08:49,534] Trial 5 finished with value: 0.9704063252773985 and parameters: {'n_estimators': 1000, 'learning_rate': 0.0734144386308604, 'num_leaves': 47, 'max_depth': 11, 'min_child_samples': 40, 'subsample': 0.7977565802216519, 'colsample_bytree': 0.980504506537954, 'reg_alpha': 7.445730054710665e-05, 'reg_lambda': 1.4428609909874822e-08}. Best is trial 5 with value: 0.9704063252773985.
# [I 2025-09-03 10:09:01,329] Trial 6 finished with value: 0.9589601275183333 and parameters: {'n_estimators': 1000, 'learning_rate': 0.001748712184750747, 'num_leaves': 47, 'max_depth': 9, 'min_child_samples': 20, 'subsample': 0.7898051378139008, 'colsample_bytree': 0.6168354281908495, 'reg_alpha': 8.983865741901254e-08, 'reg_lambda': 0.006343553994339401}. Best is trial 5 with value: 0.9704063252773985.
# [I 2025-09-03 10:09:04,061] Trial 7 finished with value: 0.9630524486931569 and parameters: {'n_estimators': 700, 'learning_rate': 0.013146958060924746, 'num_leaves': 143, 'max_depth': 4, 'min_child_samples': 40, 'subsample': 0.9148179897082047, 'colsample_bytree': 0.6933874457521291, 'reg_alpha': 0.016672225424458488, 'reg_lambda': 7.023459720277172e-08}. Best is trial 5 with value: 0.9704063252773985.
# [I 2025-09-03 10:09:05,932] Trial 8 finished with value: 0.9448627722755155 and parameters: {'n_estimators': 300, 'learning_rate': 0.002864972292023533, 'num_leaves': 127, 'max_depth': 5, 'min_child_samples': 45, 'subsample': 0.8399520601230345, 'colsample_bytree': 0.8979423517895182, 'reg_alpha': 5.974672368609965e-07, 'reg_lambda': 2.444100264773903e-08}. Best is trial 5 with value: 0.9704063252773985.
# [I 2025-09-03 10:09:13,719] Trial 9 finished with value: 0.9669103676724882 and parameters: {'n_estimators': 800, 'learning_rate': 0.008025162622604515, 'num_leaves': 135, 'max_depth': 7, 'min_child_samples': 35, 'subsample': 0.9537231031436628, 'colsample_bytree': 0.6720264120557801, 'reg_alpha': 0.00487371462797814, 'reg_lambda': 3.1617945713671705e-07}. Best is trial 5 with value: 0.9704063252773985.
# [I 2025-09-03 10:09:21,056] Trial 10 finished with value: 0.9699284927778076 and parameters: {'n_estimators': 1200, 'learning_rate': 0.12241188266151576, 'num_leaves': 183, 'max_depth': -1, 'min_child_samples': 5, 'subsample': 0.6347898659252734, 'colsample_bytree': 0.9950319435248447, 'reg_alpha': 0.0001391286175607206, 'reg_lambda': 1.366798943301663e-05}. Best is trial 5 with value: 0.9704063252773985.
# [I 2025-09-03 10:09:29,382] Trial 11 finished with value: 0.9709592926839768 and parameters: {'n_estimators': 1100, 'learning_rate': 0.08389686683034887, 'num_leaves': 255, 'max_depth': 12, 'min_child_samples': 55, 'subsample': 0.7466221810394268, 'colsample_bytree': 0.9980269229555672, 'reg_alpha': 0.0004599222115890625, 'reg_lambda': 4.659053215406283e-05}. Best is trial 11 with value: 0.9709592926839768.
# [I 2025-09-03 10:09:35,115] Trial 12 finished with value: 0.970462099882973 and parameters: {'n_estimators': 900, 'learning_rate': 0.1546603156134214, 'num_leaves': 183, 'max_depth': 14, 'min_child_samples': 55, 'subsample': 0.7407431253393436, 'colsample_bytree': 0.9979807760865733, 'reg_alpha': 0.00011925896546388479, 'reg_lambda': 8.658748411312948e-06}. Best is trial 11 with value: 0.9709592926839768.
# [I 2025-09-03 10:09:39,150] Trial 13 finished with value: 0.9697256954288547 and parameters: {'n_estimators': 900, 'learning_rate': 0.19697658676575835, 'num_leaves': 191, 'max_depth': 15, 'min_child_samples': 60, 'subsample': 0.7259291885624687, 'colsample_bytree': 0.7606119418206864, 'reg_alpha': 0.00048330918679377404, 'reg_lambda': 1.2371713520870635e-05}. Best is trial 11 with value: 0.9709592926839768.
# [I 2025-09-03 10:09:51,943] Trial 14 finished with value: 0.9698865823303041 and parameters: {'n_estimators': 1200, 'learning_rate': 0.06440525756501307, 'num_leaves': 255, 'max_depth': 13, 'min_child_samples': 50, 'subsample': 0.725207866680666, 'colsample_bytree': 0.9566115602585246, 'reg_alpha': 5.94852761694885e-06, 'reg_lambda': 2.3569157870791603e-06}. Best is trial 11 with value: 0.9709592926839768.
# [I 2025-09-03 10:09:55,986] Trial 15 finished with value: 0.9703462293107703 and parameters: {'n_estimators': 900, 'learning_rate': 0.18728044183929113, 'num_leaves': 199, 'max_depth': 14, 'min_child_samples': 55, 'subsample': 0.6084433659732993, 'colsample_bytree': 0.808333614371432, 'reg_alpha': 0.0010809110166844708, 'reg_lambda': 0.00012441168745809558}. Best is trial 11 with value: 0.9709592926839768.
# [I 2025-09-03 10
# [I 2025-09-03 10:26:50,192] Trial 95 finished with value: 0.9716980668409164 and parameters: {'n_estimators': 800, 'learning_rate': 0.09067346396993788, 'num_leaves': 31, 'max_depth': 16, 'min_child_samples': 30, 'subsample': 0.8886344938878071, 'colsample_bytree': 0.7532247465755111, 'reg_alpha': 7.951659643373352e-06, 'reg_lambda': 1.6198070925817377e-08}. Best is trial 95 with value: 0.9716980668409164.
# [I 2025-09-03 10:26:56,251] Trial 96 finished with value: 0.9711774578832614 and parameters: {'n_estimators': 700, 'learning_rate': 0.1558419757651325, 'num_leaves': 31, 'max_depth': 14, 'min_child_samples': 30, 'subsample': 0.9035286040408355, 'colsample_bytree': 0.7363759066009906, 'reg_alpha': 4.613724358261105e-06, 'reg_lambda': 1.6055360625259257e-08}. Best is trial 95 with value: 0.9716980668409164.
# [I 2025-09-03 10:27:02,696] Trial 97 finished with value: 0.9709700877708107 and parameters: {'n_estimators': 800, 'learning_rate': 0.14092642608282896, 'num_leaves': 31, 'max_depth': 14, 'min_child_samples': 30, 'subsample': 0.9024786591290099, 'colsample_bytree': 0.7346368608089561, 'reg_alpha': 4.693672661091849e-06, 'reg_lambda': 1.6210479684448574e-08}. Best is trial 95 with value: 0.9716980668409164.
# [I 2025-09-03 10:27:09,992] Trial 98 finished with value: 0.971343744239318 and parameters: {'n_estimators': 800, 'learning_rate': 0.12115702035654645, 'num_leaves': 31, 'max_depth': 14, 'min_child_samples': 30, 'subsample': 0.9187111676529057, 'colsample_bytree': 0.7528145792459219, 'reg_alpha': 1.4186189086652434e-06, 'reg_lambda': 1.3822514571174787e-08}. Best is trial 95 with value: 0.9716980668409164.
# [I 2025-09-03 10:27:16,438] Trial 99 finished with value: 0.9710773068728822 and parameters: {'n_estimators': 800, 'learning_rate': 0.17475388872762515, 'num_leaves': 39, 'max_depth': 15, 'min_child_samples': 25, 'subsample': 0.9191188408462262, 'colsample_bytree': 0.7504477092218537, 'reg_alpha': 1.3448954278562799e-06, 'reg_lambda': 9.06608600635012e-08}. Best is trial 95 with value: 0.9716980668409164.
# Best Params: {'n_estimators': 800, 'learning_rate': 0.09067346396993788, 'num_leaves': 31, 'max_depth': 16, 'min_child_samples': 30, 'subsample': 0.8886344938878071, 'colsample_bytree': 0.7532247465755111, 'reg_alpha': 7.951659643373352e-06, 'reg_lambda': 1.6198070925817377e-08}

# %% [markdown]
# #### 모델 적용

# %%
best_model = LGBMClassifier(**best_params, objective="binary", class_weight="balanced", random_state=42)

best_model.fit(X_train_res, y_train_res)
# Out:
# LGBMClassifier(class_weight='balanced', colsample_bytree=0.7532247465755111,
#                learning_rate=0.09067346396993788, max_depth=16,
#                min_child_samples=30, n_estimators=800, objective='binary',
#                random_state=42, reg_alpha=7.951659643373352e-06,
#                reg_lambda=1.6198070925817377e-08, subsample=0.8886344938878071)

# %%
from sklearn.metrics import recall_score, precision_score, classification_report, confusion_matrix

pos_prob_val = best_model.predict_proba(X_val_scaled)[:, 1]

# 목표 재현율을 만족하는 임계값 탐색
target_recall = 0.80
ths = np.linspace(0.0, 1.0, 1001)   # 0~1 사이 0.001 간격
best_t, best_precision = 0.5, -1

for t in ths:
    pred = (pos_prob_val >= t).astype(int)
    r = recall_score(y_val, pred)
    if r >= target_recall:
        p = precision_score(y_val, pred)
        if p > best_precision:
            best_precision, best_t = p, t

print(f"\n[Validation] chosen threshold = {best_t:.3f} "
      f"(precision={best_precision:.3f}, target recall ≥ {target_recall})")

y_val_pred = (pos_prob_val >= best_t).astype(int)

# 결과 확인
print(classification_report(y_val, y_val_pred, digits=2))
print("Confusion Matrix:\n", confusion_matrix(y_val, y_val_pred))
# Out:
# [Validation] chosen threshold = 0.058 (precision=0.386, target recall ≥ 0.8)
#               precision    recall  f1-score   support
#
#            0       0.96      0.78      0.86      1553
#            1       0.39      0.80      0.52       262
#
#     accuracy                           0.79      1815
#    macro avg       0.67      0.79      0.69      1815
# weighted avg       0.88      0.79      0.81      1815
#
# Confusion Matrix:
#  [[1219  334]
#  [  52  210]]

# %% [markdown]
# ### 최종 모델

# %%
X_train_final = np.vstack([X_train_scaled, X_val_scaled])
y_train_final = np.hstack([y_train, y_val])

print("Train shape:", X_train_final.shape, y_train_final.shape)
# Out:
# Train shape: (9075, 156) (9075,)

# %%
smote = SMOTE(random_state=42, k_neighbors=3)
smote_enn = SMOTEENN(random_state=42, smote=smote)
X_train_final_res, y_train_final_res = smote_enn.fit_resample(X_train_final, y_train_final)

print("최종 학습 데이터 분포:\n", pd.Series(y_train_final_res).value_counts())
# Out:
# 최종 학습 데이터 분포:
#  1    7676
# 0    3535
# Name: count, dtype: int64

# %%
final_model = LGBMClassifier(
    **best_params,
    objective="binary",
    class_weight="balanced",
    random_state=42
)

final_model.fit(X_train_final_res, y_train_final_res)
# Out:
# LGBMClassifier(class_weight='balanced', colsample_bytree=0.7532247465755111,
#                learning_rate=0.09067346396993788, max_depth=16,
#                min_child_samples=30, n_estimators=800, objective='binary',
#                random_state=42, reg_alpha=7.951659643373352e-06,
#                reg_lambda=1.6198070925817377e-08, subsample=0.8886344938878071)

# %%
pos_prob_test = final_model.predict_proba(X_test_scaled)[:, 1]
y_test_pred = (pos_prob_test >= best_t).astype(int)        # Validation에서 찾은 threshold 적용

print("\n=== Final Test Report (Threshold tuned at Validation) ===")
print(classification_report(y_test, y_test_pred, digits=2))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_test_pred))
# Out:
# === Final Test Report (Threshold tuned at Validation) ===
#               precision    recall  f1-score   support
#
#            0       0.96      0.77      0.85      1941
#            1       0.37      0.83      0.51       328
#
#     accuracy                           0.77      2269
#    macro avg       0.67      0.80      0.68      2269
# weighted avg       0.88      0.77      0.80      2269
#
#
# Confusion Matrix:
# [[1486  455]
#  [  57  271]]

# %%
y_true_test = y_test.values

print("Shapes:", pos_prob_test.shape, y_true_test.shape)

# 인덱스 추출
tn_idx = np.where((y_true_test == 0) & (y_test_pred == 0))[0]
tp_idx = np.where((y_true_test == 1) & (y_test_pred == 1))[0]
fp_idx = np.where((y_true_test == 0) & (y_test_pred == 1))[0]
fn_idx = np.where((y_true_test == 1) & (y_test_pred == 0))[0]

print("TN:", tn_idx[:5])
print("TP:", tp_idx[:5])
print("FP:", fp_idx[:5])
print("FN:", fn_idx[:5])
# Out:
# Shapes: (2269,) (2269,)
# TN: [ 1  4  5 11 13]
# TP: [ 2  8 10 14 16]
# FP: [0 3 6 7 9]
# FN: [ 12  29  44 107 121]

# %% [markdown]
# #### feature importance 시각화

# %%
# feature importance (gain 기준)
importance = pd.DataFrame(final_model.booster_.feature_importance(importance_type='gain'), index=X_train.columns, columns=["importance"]).sort_values(by="importance",ascending = True).tail(20)
importance

# 변수중요도 비율로 전환
importance['importance_pct'] = importance['importance'] / importance['importance'].sum() * 100
importance.head(20)
# Out:
#                   importance  importance_pct
# wsituation5       718.029597        1.039593
# wwa3              886.414853        1.283388
# emp_manaqual_c    910.672018        1.318509
# emp_comp_ass_b    968.291762        1.401933
# wwa1             1038.584557        1.503706
# who3             1202.823492        1.741498
# wstat5           1303.623342        1.887440
# emp_manaqual_b   1421.791076        2.058529
# emp_manaqual_e   1445.658628        2.093085
# wsituation4      1507.261686        2.182276
# wsituation13     1944.364808        2.815133
# wstat1           2180.017952        3.156321
# wstat3           2219.245341        3.213116
# who1             2350.522754        3.403185
# wsituation7      3115.917678        4.511356
# emp_comp_ass_a   3799.848886        5.501580
# wstat2           4755.503786        6.885217
# wsituation3      9138.589666       13.231232
# wsituation11    12185.268206       17.642341
# wsituation8     15975.889422       23.130560

# %%
importance['importance_pct'].plot.barh()
plt.show()

# %% [markdown]
# #### Shap 변수 중요도 확인

# %%
# LightGBM 모델 학습된 객체: final_model
explainer = shap.TreeExplainer(final_model)

# %%
shap_values = explainer(X_train_res)

shap_importance = np.abs(shap_values.values).mean(axis=0)

fi_shap = pd.DataFrame({
    "feature": X_train.columns,          # 원본 feature 이름
    "importance_shap": shap_importance
}).sort_values(by="importance_shap", ascending=False).reset_index(drop=True)

print(fi_shap.head(20))
# Out:
#            feature  importance_shap
# 0      wsituation8         1.712962
# 1      wsituation7         1.266894
# 2     wsituation11         1.213341
# 3     wsituation13         1.167178
# 4           wstat2         0.998419
# 5             who1         0.938056
# 6   emp_comp_ass_a         0.666188
# 7      wsituation3         0.663543
# 8   emp_manaqual_b         0.617353
# 9           wstat1         0.611786
# 10            who3         0.558303
# 11  emp_manaqual_c         0.553860
# 12  emp_comp_ass_d         0.522273
# 13    satisfaction         0.507109
# 14    emp_winflu_c         0.489146
# 15     hazard_psy3         0.468624
# 16            who2         0.441224
# 17     wsituation5         0.439137
# 18     wsituation4         0.433978
# 19  emp_manaqual_e         0.416983

# %%
# summary plot

shap.summary_plot(
    shap_values,
    X_train_res,
    feature_names=X_train.columns  
)

# %%
shap.initjs()

X_train_res_df = pd.DataFrame(X_train_res, columns=X_train.columns)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...

# %%
# 샘플 force plot

i = 8
shap.force_plot(
    explainer.expected_value,
    shap_values.values[i, :],
    X_train_res_df.iloc[i, :]
)
# Out:
# <div id='iGO4FQ1UVXWH244MBADU5'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 10.288761497271777, "outValue": -2.854679426544852, "link": "identity", "featureNames": ["wtime_length5", "compsize_group", "woutside_group", "compsize_group_a", "wday_week_group_a", "woutside4_group_a", "earning2_group_b", "emp_stat", "emp_con_term", "emp_keep", "emp_own_mgmt", "emp_fptime", "emp_wage", "emp_stat_sp", "income_pos_a", "income_pos_b", "income_pos_c", "income_pos_d", "income_pos_e", "income_pos_f", "income_pos_g", "income_pos_h", "income_pos_i", "income_pos_j", "emp_place", "emp_suggest_a", "emp_suggest_b", "emp_boss_gender", "emp_manaqual_b", "emp_manaqual_c", "emp_manaqual_d", "emp_manaqual_e", "emp_comp_ass_a", "emp_comp_ass_b", "emp_comp_ass_c", "emp_comp_ass_d", "emp_comp_ass_e", "emp_comp_ass_f", "emp_rep", "emp_winflu_c", "emp_tra_c", "emp_tra_d", "wsector", "comp_size_a", "comp_female", "comp_sjob", "ch_tech", "ch_ps", "imte1", "imte2", "imte3", "imte4", "imte5", "safeinform", "wsituation3", "wsituation4", "wsituation5", "wsituation11", "wsituation6", "wsituation7", "wsituation8", "wsituation13", "wstat1", "wstat2", "wstat3", "wstat5", "wstat6", "wstat7", "emo_manual", "asb5", "asb6", "asb7", "wtime_con1", "wday", "wtime_night_a", "wtime_sun_a", "wtime_sat_a", "wtime_long_a", "wtime_night2", "wtime_night3", "wtime_resilience", "wtime_arr_a", "wtime_ftwork", "wtime_ftcomtool", "wtime_private", "hazard_phy_b", "hazard_erg_a", "hazard_erg_b", "hazard_erg_c", "hazard_erg_d", "hazard_erg_e", "winten1_a", "winten1_b", "decla_c", "winterrupt1", "condim1", "condim2", "condim3", "condim4", "condim5", "condim6", "ass_cust1", "alter_task1", "wteam1", "satisfaction", "wplace4", "wplace3", "wplace2", "wplace1", "wpalce_ch", "wtime_length1", "wtime_length2", "wtime_length3", "wtime_length4", "job1", "wtime", "wbalance", "wwa1", "wwa3", "wwa4", "wwa5", "heal_risk", "heal_wsick1", "asb1", "asb2", "asb3", "asb4", "heal_aff", "heal_cond", "heal_illhe", "heal_lim1", "heal_prob1", "heal_prob2", "heal_prob3", "heal_prob4", "heal_prob5", "heal_prob6", "heal_prob8", "who1", "who2", "who3", "who4", "who5", "woutside3", "woutside5", "income_con", "income_bal", "hazard_psy1", "hazard_psy2", "hazard_psy3", "heal_abs1_group", "ctime_group", "disc_group", "decla_group", "winten2_group", "winten3_group"], "features": {"0": {"effect": -0.0024665998946212593, "value": 1.0}, "1": {"effect": 0.01003082055354665, "value": 0.2727272727272727}, "2": {"effect": 0.001545327684316873, "value": 0.0}, "3": {"effect": 0.05125535094472135, "value": 0.0}, "4": {"effect": -0.03733692862531059, "value": 0.5}, "5": {"effect": -0.061637241197071944, "value": 0.5}, "6": {"effect": -0.27041684049782116, "value": 0.5}, "7": {"effect": -0.11716445379527356, "value": 0.0}, "8": {"effect": -0.048004431838581545, "value": 1.0}, "9": {"effect": -0.011270120165141666, "value": 0.0}, "11": {"effect": -0.19384533141083035, "value": 0.0}, "12": {"effect": -0.0008006706618761889, "value": 0.0}, "13": {"effect": 0.003684695380953577, "value": 1.0}, "14": {"effect": 0.0052879154931638655, "value": 0.0}, "15": {"effect": 0.003526743632027346, "value": 1.0}, "16": {"effect": 0.10083772390468854, "value": 0.0}, "17": {"effect": -0.48461091301447273, "value": 0.0}, "18": {"effect": -0.010815081283780012, "value": 0.0}, "19": {"effect": -0.07505618958489105, "value": 1.0}, "20": {"effect": 0.06688571936016824, "value": 1.0}, "21": {"effect": 0.2257351853890027, "value": 0.0}, "22": {"effect": -0.022083934356640834, "value": 1.0}, "23": {"effect": 0.07555993650498957, "value": 1.0}, "25": {"effect": 0.05363707242067117, "value": 1.0}, "26": {"effect": 0.13555803622365242, "value": 1.0}, "27": {"effect": -0.11412890897083224, "value": 1.0}, "28": {"effect": -0.6833802317563793, "value": 0.25}, "29": {"effect": -0.05698415158434305, "value": 0.5}, "30": {"effect": -0.18904384969173424, "value": 0.25}, "31": {"effect": -0.6950020189338892, "value": 0.25}, "32": {"effect": -0.8205383 ...

# %%
# 샘플 force plot

i = 5
shap.force_plot(
    explainer.expected_value,
    shap_values.values[i, :],
    X_train_res_df.iloc[i, :]
)
# Out:
# <div id='i8H8BVC2TGCQXDBP4VO8D'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 10.288761497271777, "outValue": -13.258161677028875, "link": "identity", "featureNames": ["wtime_length5", "compsize_group", "woutside_group", "compsize_group_a", "wday_week_group_a", "woutside4_group_a", "earning2_group_b", "emp_stat", "emp_con_term", "emp_keep", "emp_own_mgmt", "emp_fptime", "emp_wage", "emp_stat_sp", "income_pos_a", "income_pos_b", "income_pos_c", "income_pos_d", "income_pos_e", "income_pos_f", "income_pos_g", "income_pos_h", "income_pos_i", "income_pos_j", "emp_place", "emp_suggest_a", "emp_suggest_b", "emp_boss_gender", "emp_manaqual_b", "emp_manaqual_c", "emp_manaqual_d", "emp_manaqual_e", "emp_comp_ass_a", "emp_comp_ass_b", "emp_comp_ass_c", "emp_comp_ass_d", "emp_comp_ass_e", "emp_comp_ass_f", "emp_rep", "emp_winflu_c", "emp_tra_c", "emp_tra_d", "wsector", "comp_size_a", "comp_female", "comp_sjob", "ch_tech", "ch_ps", "imte1", "imte2", "imte3", "imte4", "imte5", "safeinform", "wsituation3", "wsituation4", "wsituation5", "wsituation11", "wsituation6", "wsituation7", "wsituation8", "wsituation13", "wstat1", "wstat2", "wstat3", "wstat5", "wstat6", "wstat7", "emo_manual", "asb5", "asb6", "asb7", "wtime_con1", "wday", "wtime_night_a", "wtime_sun_a", "wtime_sat_a", "wtime_long_a", "wtime_night2", "wtime_night3", "wtime_resilience", "wtime_arr_a", "wtime_ftwork", "wtime_ftcomtool", "wtime_private", "hazard_phy_b", "hazard_erg_a", "hazard_erg_b", "hazard_erg_c", "hazard_erg_d", "hazard_erg_e", "winten1_a", "winten1_b", "decla_c", "winterrupt1", "condim1", "condim2", "condim3", "condim4", "condim5", "condim6", "ass_cust1", "alter_task1", "wteam1", "satisfaction", "wplace4", "wplace3", "wplace2", "wplace1", "wpalce_ch", "wtime_length1", "wtime_length2", "wtime_length3", "wtime_length4", "job1", "wtime", "wbalance", "wwa1", "wwa3", "wwa4", "wwa5", "heal_risk", "heal_wsick1", "asb1", "asb2", "asb3", "asb4", "heal_aff", "heal_cond", "heal_illhe", "heal_lim1", "heal_prob1", "heal_prob2", "heal_prob3", "heal_prob4", "heal_prob5", "heal_prob6", "heal_prob8", "who1", "who2", "who3", "who4", "who5", "woutside3", "woutside5", "income_con", "income_bal", "hazard_psy1", "hazard_psy2", "hazard_psy3", "heal_abs1_group", "ctime_group", "disc_group", "decla_group", "winten2_group", "winten3_group"], "features": {"0": {"effect": 0.0003798152588498248, "value": 1.0}, "1": {"effect": 0.04492221438334034, "value": 0.0}, "2": {"effect": 0.0014483944855261611, "value": 0.0}, "3": {"effect": 0.027029263780660288, "value": 0.0}, "4": {"effect": -0.004918740103739913, "value": 0.5}, "5": {"effect": -0.30777117602532694, "value": 1.0}, "6": {"effect": -0.16052312725400214, "value": 0.5}, "7": {"effect": 0.6057496108241472, "value": 0.5}, "8": {"effect": 0.03017286168485101, "value": 0.0}, "9": {"effect": 0.17571063804750608, "value": 1.0}, "11": {"effect": -0.18144596397451232, "value": 0.0}, "12": {"effect": -0.0009737165219139521, "value": 0.0}, "13": {"effect": 0.003679947043471687, "value": 1.0}, "14": {"effect": 0.0054280403032215966, "value": 0.0}, "15": {"effect": 0.021722605468328913, "value": 1.0}, "16": {"effect": -0.11456867116080732, "value": 1.0}, "17": {"effect": -0.004691698655791228, "value": 1.0}, "18": {"effect": 0.035585338096516504, "value": 0.0}, "19": {"effect": -0.11431166113017772, "value": 1.0}, "20": {"effect": 0.046441810015843715, "value": 1.0}, "21": {"effect": -0.1954689100400216, "value": 1.0}, "22": {"effect": -0.02758727137337909, "value": 1.0}, "23": {"effect": 0.15722223721594406, "value": 1.0}, "25": {"effect": 0.060534448890309484, "value": 1.0}, "26": {"effect": 0.12993065380111032, "value": 1.0}, "27": {"effect": -0.08675670152865786, "value": 1.0}, "28": {"effect": -0.9720083048126029, "value": 0.0}, "29": {"effect": -0.33542091164145943, "value": 0.25}, "30": {"effect": -0.22884631646347986, "value": 0.25}, "31": {"effect": -0.5591176614588927, "value": 0.25}, "32": {"effect": -0.916231375985531, "value ...

# %%
# 샘플 force plot

i = 16
shap.force_plot(
    explainer.expected_value,
    shap_values.values[i, :],
    X_train_res_df.iloc[i, :]
)
# Out:
# <div id='iJQHKUOIRD99S2U0G9WTF'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 10.288761497271777, "outValue": -7.195754353662293, "link": "identity", "featureNames": ["wtime_length5", "compsize_group", "woutside_group", "compsize_group_a", "wday_week_group_a", "woutside4_group_a", "earning2_group_b", "emp_stat", "emp_con_term", "emp_keep", "emp_own_mgmt", "emp_fptime", "emp_wage", "emp_stat_sp", "income_pos_a", "income_pos_b", "income_pos_c", "income_pos_d", "income_pos_e", "income_pos_f", "income_pos_g", "income_pos_h", "income_pos_i", "income_pos_j", "emp_place", "emp_suggest_a", "emp_suggest_b", "emp_boss_gender", "emp_manaqual_b", "emp_manaqual_c", "emp_manaqual_d", "emp_manaqual_e", "emp_comp_ass_a", "emp_comp_ass_b", "emp_comp_ass_c", "emp_comp_ass_d", "emp_comp_ass_e", "emp_comp_ass_f", "emp_rep", "emp_winflu_c", "emp_tra_c", "emp_tra_d", "wsector", "comp_size_a", "comp_female", "comp_sjob", "ch_tech", "ch_ps", "imte1", "imte2", "imte3", "imte4", "imte5", "safeinform", "wsituation3", "wsituation4", "wsituation5", "wsituation11", "wsituation6", "wsituation7", "wsituation8", "wsituation13", "wstat1", "wstat2", "wstat3", "wstat5", "wstat6", "wstat7", "emo_manual", "asb5", "asb6", "asb7", "wtime_con1", "wday", "wtime_night_a", "wtime_sun_a", "wtime_sat_a", "wtime_long_a", "wtime_night2", "wtime_night3", "wtime_resilience", "wtime_arr_a", "wtime_ftwork", "wtime_ftcomtool", "wtime_private", "hazard_phy_b", "hazard_erg_a", "hazard_erg_b", "hazard_erg_c", "hazard_erg_d", "hazard_erg_e", "winten1_a", "winten1_b", "decla_c", "winterrupt1", "condim1", "condim2", "condim3", "condim4", "condim5", "condim6", "ass_cust1", "alter_task1", "wteam1", "satisfaction", "wplace4", "wplace3", "wplace2", "wplace1", "wpalce_ch", "wtime_length1", "wtime_length2", "wtime_length3", "wtime_length4", "job1", "wtime", "wbalance", "wwa1", "wwa3", "wwa4", "wwa5", "heal_risk", "heal_wsick1", "asb1", "asb2", "asb3", "asb4", "heal_aff", "heal_cond", "heal_illhe", "heal_lim1", "heal_prob1", "heal_prob2", "heal_prob3", "heal_prob4", "heal_prob5", "heal_prob6", "heal_prob8", "who1", "who2", "who3", "who4", "who5", "woutside3", "woutside5", "income_con", "income_bal", "hazard_psy1", "hazard_psy2", "hazard_psy3", "heal_abs1_group", "ctime_group", "disc_group", "decla_group", "winten2_group", "winten3_group"], "features": {"0": {"effect": -0.11279232952252627, "value": 0.0}, "1": {"effect": -0.09203127151806095, "value": 0.2727272727272727}, "2": {"effect": 0.0015243252872496173, "value": 0.0}, "3": {"effect": 0.03209576836323074, "value": 0.0}, "4": {"effect": -0.02354267424470653, "value": 0.5}, "5": {"effect": -0.13848340561001762, "value": 0.0}, "6": {"effect": -0.29610000679126647, "value": 0.5}, "7": {"effect": -0.10688539535853846, "value": 0.0}, "8": {"effect": -0.13300816041407576, "value": 1.0}, "9": {"effect": -0.034747664386734156, "value": 0.0}, "11": {"effect": -0.09017775414167194, "value": 0.0}, "12": {"effect": -0.000794487326032478, "value": 0.0}, "13": {"effect": 0.0036375589460639697, "value": 1.0}, "14": {"effect": 0.004594417795378626, "value": 0.0}, "15": {"effect": 0.011491533513939747, "value": 1.0}, "16": {"effect": -0.12398807139209227, "value": 1.0}, "17": {"effect": -0.02281535721288623, "value": 1.0}, "18": {"effect": -0.13134962414804616, "value": 1.0}, "19": {"effect": -0.059502633992044786, "value": 1.0}, "20": {"effect": 0.03478411240971676, "value": 1.0}, "21": {"effect": 0.09463663760091019, "value": 0.0}, "22": {"effect": -0.01037982267135719, "value": 1.0}, "23": {"effect": 0.03999138916027291, "value": 1.0}, "25": {"effect": 0.04900527555070849, "value": 1.0}, "26": {"effect": 0.0823978025137822, "value": 1.0}, "27": {"effect": -0.0803018304749301, "value": 1.0}, "28": {"effect": -0.4579421621836968, "value": 0.25}, "29": {"effect": -0.8116836164862905, "value": 0.0}, "30": {"effect": 0.15412279624666278, "value": 0.5}, "31": {"effect": -0.6002806462198285, "value": 0.25}, "32": {"effect": -0.62453929463143 ...

# %%
i = 6  # 첫 번째 샘플

shap.decision_plot(
    explainer.expected_value,
    shap_values.values[i, :],
    X_train_res_df.iloc[i, :]
)

# %% [markdown]
# ## Feature Selection 2차

# %%
import numpy as np
import pandas as pd
from collections import Counter
from sklearn.model_selection import train_test_split
from lightgbm import LGBMClassifier
import seaborn as sns
import matplotlib.pyplot as plt

# -------------------------
# 1. 반복 학습 & 변수 선택 기록
# -------------------------
n_iter = 20          # 반복 횟수 (논문에서는 20번)
top_n = 50           # 매 반복에서 상위 N개 변수 선택
selected_counts = Counter()
importance_values = []

for i in range(n_iter):
    # 데이터 샘플링 (train/val split, 부트스트랩)
    X_tr, X_val, y_tr, y_val = train_test_split(
        train_X, train_Y, test_size=0.2, stratify=train_Y, random_state=i
    )
    
    # 모델 학습
    model = LGBMClassifier(
        objective="multiclass",
        num_class=3,
        class_weight="balanced",
        random_state=i,
        n_estimators=200
    )
    model.fit(X_tr, y_tr)
    
    # 변수 중요도 (gain 기준)
    importances = model.booster_.feature_importance(importance_type="gain")
    features = model.booster_.feature_name()
    
    # 상위 N개 선택
    top_idx = np.argsort(importances)[::-1][:top_n]
    for idx in top_idx:
        selected_counts[features[idx]] += 1
    
    # 평균 importance 계산용 저장
    importance_values.append(importances)

# -------------------------
# 2. 평균 importance와 % times selected 계산
# -------------------------
mean_importance = np.mean(importance_values, axis=0)
df_importance = pd.DataFrame({
    "feature": features,
    "importance_gain": mean_importance,
    "%_times_selected": [selected_counts[f]/n_iter*100 for f in features]
})

# 상위 20개만 정렬
df_top = df_importance.sort_values(by="importance_gain", ascending=False).head(top_n)

# -------------------------
# 3. Figure 1 스타일 시각화
# -------------------------
fig, ax1 = plt.subplots(figsize=(12,6))

# 막대그래프 (평균 gain importance)
sns.barplot(
    data=df_top,
    x="feature", y="importance_gain",
    color="skyblue", ax=ax1
)
ax1.set_ylabel("Mean importance (gain)", fontsize=12)
ax1.set_xlabel("Feature", fontsize=12)
ax1.tick_params(axis='x', rotation=90)

# 2축 (% times selected)
ax2 = ax1.twinx()
ax2.plot(df_top["feature"], df_top["%_times_selected"], color="red", marker="o")
ax2.set_ylabel("% times selected (out of 20 runs)", fontsize=12)

plt.title(f"Top {top_n} Feature importance + % times selected", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001024 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 697
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000935 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 696
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001127 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 697
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001187 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 698
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001053 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 697
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000997 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 698
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001027 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 697
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001246 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 698
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001002 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 698
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000996 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 697
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000985 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 696
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000963 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 698
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001198 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 698
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001105 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 698
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001064 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 698
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003496 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 697
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001028 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 697
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001283 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 698
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001128 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 698
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000940 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 697
# [LightGBM] [Info] Number of data points in the train set: 9075, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612

# %%
from imblearn.under_sampling import RandomUnderSampler

# -------------------------
# 1. 반복 학습 & 변수 선택 기록
# -------------------------
n_iter = 20          # 반복 횟수 (논문에서는 20번)
top_n = 50           # 매 반복에서 상위 N개 변수 선택
selected_counts = Counter()
importance_values = []

for i in range(n_iter):
    # 데이터 샘플링 (train/val split, 부트스트랩)
    X_tr, X_val, y_tr, y_val = train_test_split(
        train_X, train_Y, test_size=0.2, stratify=train_Y, random_state=i
    )
    
    # 다운샘플링
    rus = RandomUnderSampler(random_state=i)
    X_tr, y_tr = rus.fit_resample(X_tr, y_tr)
    
    # 모델 학습
    model = LGBMClassifier(
        objective="multiclass",
        num_class=3,
        class_weight="balanced",
        random_state=i,
        n_estimators=200
    )
    model.fit(X_tr, y_tr)
    
    # 변수 중요도 (gain 기준)
    importances = model.booster_.feature_importance(importance_type="gain")
    features = model.booster_.feature_name()
    
    # 상위 N개 선택
    top_idx = np.argsort(importances)[::-1][:top_n]
    for idx in top_idx:
        selected_counts[features[idx]] += 1
    
    # 평균 importance 계산용 저장
    importance_values.append(importances)

# -------------------------
# 2. 평균 importance와 % times selected 계산
# -------------------------
mean_importance = np.mean(importance_values, axis=0)
df_importance = pd.DataFrame({
    "feature": features,
    "importance_gain": mean_importance,
    "%_times_selected": [selected_counts[f]/n_iter*100 for f in features]
})

# 상위 20개만 정렬
df_top = df_importance.sort_values(by="importance_gain", ascending=False).head(top_n)

# -------------------------
# 3. Figure 1 스타일 시각화
# -------------------------
fig, ax1 = plt.subplots(figsize=(12,6))

# 막대그래프 (평균 gain importance)
sns.barplot(
    data=df_top,
    x="feature", y="importance_gain",
    color="skyblue", ax=ax1
)
ax1.set_ylabel("Mean importance (gain)", fontsize=12)
ax1.set_xlabel("Feature", fontsize=12)
ax1.tick_params(axis='x', rotation=90)

# 2축 (% times selected)
ax2 = ax1.twinx()
ax2.plot(df_top["feature"], df_top["%_times_selected"], color="red", marker="o")
ax2.set_ylabel("% times selected (out of 20 runs)", fontsize=12)

plt.title(f"Top {top_n} Feature importance + % times selected", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000951 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 636
# [LightGBM] [Info] Number of data points in the train set: 519, number of used features: 132
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000410 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 633
# [LightGBM] [Info] Number of data points in the train set: 519, number of used features: 130
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
from imblearn.combine import SMOTEENN
from imblearn.over_sampling import SMOTE

# -------------------------
# 1. 반복 학습 & 변수 선택 기록
# -------------------------
n_iter = 20          # 반복 횟수 (논문에서는 20번)
top_n = 50           # 매 반복에서 상위 N개 변수 선택
selected_counts = Counter()
importance_values = []

for i in range(n_iter):
    # 데이터 샘플링 (train/val split, 부트스트랩)
    X_tr, X_val, y_tr, y_val = train_test_split(
        train_X, train_Y, test_size=0.8, stratify=train_Y, random_state=i
    )
    
    # SMOTE-ENN
    smote = SMOTE(random_state=i, k_neighbors=3)
    smote_enn = SMOTEENN(random_state=i, smote=smote)
    X_tr, y_tr = smote_enn.fit_resample(X_tr, y_tr)
    
    # 모델 학습
    model = LGBMClassifier(
        objective="multiclass",
        num_class=3,
        class_weight="balanced",
        random_state=i,
        n_estimators=200
    )
    model.fit(X_tr, y_tr)
    
    # 변수 중요도 (gain 기준)
    importances = model.booster_.feature_importance(importance_type="gain")
    features = model.booster_.feature_name()
    
    # 상위 N개 선택
    top_idx = np.argsort(importances)[::-1][:top_n]
    for idx in top_idx:
        selected_counts[features[idx]] += 1
    
    # 평균 importance 계산용 저장
    importance_values.append(importances)

# -------------------------
# 2. 평균 importance와 % times selected 계산
# -------------------------
mean_importance = np.mean(importance_values, axis=0)
df_importance = pd.DataFrame({
    "feature": features,
    "importance_gain": mean_importance,
    "%_times_selected": [selected_counts[f]/n_iter*100 for f in features]
})

# 상위 20개만 정렬
df_top = df_importance.sort_values(by="importance_gain", ascending=False).head(top_n)

# -------------------------
# 3. Figure 1 스타일 시각화
# -------------------------
fig, ax1 = plt.subplots(figsize=(12,6))

# 막대그래프 (평균 gain importance)
sns.barplot(
    data=df_top,
    x="feature", y="importance_gain",
    color="skyblue", ax=ax1
)
ax1.set_ylabel("Mean importance (gain)", fontsize=12)
ax1.set_xlabel("Feature", fontsize=12)
ax1.tick_params(axis='x', rotation=90)

# 2축 (% times selected)
ax2 = ax1.twinx()
ax2.plot(df_top["feature"], df_top["%_times_selected"], color="red", marker="o")
ax2.set_ylabel("% times selected (out of 20 runs)", fontsize=12)

plt.title(f"Top {top_n} Feature importance + % times selected", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004698 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 27674
# [LightGBM] [Info] Number of data points in the train set: 4658, number of used features: 146
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005288 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 27397
# [LightGBM] [Info] Number of data points in the train set: 4843, number of used features: 147
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004524 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 27718
# [LightGBM] [Info] Number of data points in the train set: 4675, number of used features: 143
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004876 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 27044
# [LightGBM] [Info] Number of data points in the train set: 4585, number of used features: 146
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004935 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 28342
# [LightGBM] [Info] Number of data points in the train set: 4678, number of used features: 147
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005279 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 28083
# [LightGBM] [Info] Number of data points in the train set: 4632, number of used features: 146
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004952 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 28057
# [LightGBM] [Info] Number of data points in the train set: 4651, number of used features: 146
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004838 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 27998
# [LightGBM] [Info] Number of data points in the train set: 4766, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %% [markdown]
# ### RFECV 변수 선택 model

# %%
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold

# 모델 정의
final_model = LGBMClassifier(
    objective="multiclass",
    num_class=3,
    class_weight="balanced",
    random_state=42,
    n_estimators=best_iter  # 최적 반복 수 적용
)

# 교차검증 설정
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# RFECV 실행
rfecv = RFECV(
    estimator=final_model,
    step=1,                  # 한 번에 제거할 변수 개수
    cv=cv,                   # 교차검증 방식
    scoring="roc_auc_ovr",   # 다중분류 AUC (One-vs-Rest)
    n_jobs=-1
)

rfecv.fit(X_train, y_train)

print("최적 변수 개수:", rfecv.n_features_)
print("선택된 변수:", train_X.columns[rfecv.support_])
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001709 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 697
# [LightGBM] [Info] Number of data points in the train set: 6806, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001670 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 697
# [LightGBM] [Info] Number of data points in the train set: 6806, number of used features: 148
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001563 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 694
# [LightGBM] [Info] Number of data points in the train set: 6806, number of used features: 147
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001364 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 691
# [LightGBM] [Info] Number of data points in the train set: 6806, number of used features: 146
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001228 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 688
# [LightGBM] [Info] Number of data points in the train set: 6806, number of used features: 145
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001191 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 688
# [LightGBM] [Info] Number of data points in the train set: 6806, number of used features: 145
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001134 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 688
# [LightGBM] [Info] Number of data points in the train set: 6806, number of used features: 145
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001468 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 688
# [LightGBM] [Info] Number of data points in the train set: 6806, number of used features: 145
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001384 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 685
# [LightGBM] [Info] Number of data points in the train set: 6806, number of used features: 144
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001536 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 685
# [LightGBM] [Info] Number of data points in the train set: 6806, number of used features: 144
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001229 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 685
# [LightGBM] [Info] Number of data points in the train set: 6806, number of used features: 144
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001741 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 685
# [LightGBM] [Info] Number of data points in the train set: 6806, number of used features: 144
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001033 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 685
# [LightGBM] [Info] Number of data points in the train set: 6806, number of used features: 144
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001289 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 681
# [LightGBM] [Info] Number of data points in the train set: 6806, number of used features: 143
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001135 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 678
# [LightGBM] [Info] Number of data points in the train set: 6806, number of used features: 142
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001033 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 675
# [LightGBM] [Info] Number of data points in the train set: 6806, number of used features: 141
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001157 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 675
# [LightGBM] [Info] Number of data points in the train set: 6806, number of used features: 141
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# 최적 변수 개수: 141
# 선택된 변수: Index(['wtime_length5', 'compsize_group', 'woutside_group', 'compsize_group_a',
#        'wday_week_group_a', 'woutside4_group_a', 'earning2_group_b',
#        'emp_stat', 'emp_con_term', 'emp_keep',
#        ...
#        'woutside3', 'woutside5', 'income_con', 'income_bal', 'hazard_psy1',
#        'hazard_psy2', 'hazard_psy3', 'heal_abs1_group', 'ctime_group',
#        'winten2_group'],
#       dtype='object', length=141)

# %%
# 성능 그래프 (최적 변수 개수 vs CV score)
plt.figure(figsize=(8,6))

# grid_scores_ 대신 cv_results_ 사용
mean_test_scores = rfecv.cv_results_['mean_test_score']

plt.plot(range(1, len(mean_test_scores) + 1), mean_test_scores, marker='o')
plt.xlabel("Number of features selected")
plt.ylabel("CV ROC AUC")
plt.title("RFECV - Optimal number of features")
plt.grid(True)
plt.show()

# %%
# # RFECV에서 선택된 변수
# optimal_features = train_X.columns[rfecv.support_]

# # X_train에서 선택된 변수만 저장
# X_train_selected = train_X[optimal_features]
